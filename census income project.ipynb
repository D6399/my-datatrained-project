# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('census income.csv')

# %%
df
# Out:
#        Age          Workclass  Fnlwgt    Education  Education_num  \
# 0       50   Self-emp-not-inc   83311    Bachelors             13
# 1       38            Private  215646      HS-grad              9
# 2       53            Private  234721         11th              7
# 3       28            Private  338409    Bachelors             13
# 4       37            Private  284582      Masters             14
# ...    ...                ...     ...          ...            ...
# 32555   27            Private  257302   Assoc-acdm             12
# 32556   40            Private  154374      HS-grad              9
# 32557   58            Private  151910      HS-grad              9
# 32558   22            Private  201490      HS-grad              9
# 32559   52       Self-emp-inc  287927      HS-grad              9
#
#             Marital_status          Occupation    Relationship    Race  \
# 0       Married-civ-spouse     Exec-managerial         Husband   White
# ...

# %% [markdown]
# we have 32560 rows and 15 columns in our dataset.

# %%
df.head(20)
# Out:
#     Age          Workclass  Fnlwgt      Education  Education_num  \
# 0    50   Self-emp-not-inc   83311      Bachelors             13
# 1    38            Private  215646        HS-grad              9
# 2    53            Private  234721           11th              7
# 3    28            Private  338409      Bachelors             13
# 4    37            Private  284582        Masters             14
# 5    49            Private  160187            9th              5
# 6    52   Self-emp-not-inc  209642        HS-grad              9
# 7    31            Private   45781        Masters             14
# 8    42            Private  159449      Bachelors             13
# 9    37            Private  280464   Some-college             10
# 10   30          State-gov  141297      Bachelors             13
# 11   23            Private  122272      Bachelors             13
# 12   32            Private  205019     Assoc-acdm             12
# ...

# %% [markdown]
# in this we have first 20 rows of the dataset.

# %%
df.tail()
# Out:
#        Age      Workclass  Fnlwgt    Education  Education_num  \
# 32555   27        Private  257302   Assoc-acdm             12
# 32556   40        Private  154374      HS-grad              9
# 32557   58        Private  151910      HS-grad              9
# 32558   22        Private  201490      HS-grad              9
# 32559   52   Self-emp-inc  287927      HS-grad              9
#
#             Marital_status          Occupation Relationship    Race      Sex  \
# 32555   Married-civ-spouse        Tech-support         Wife   White   Female
# 32556   Married-civ-spouse   Machine-op-inspct      Husband   White     Male
# 32557              Widowed        Adm-clerical    Unmarried   White   Female
# 32558        Never-married        Adm-clerical    Own-child   White     Male
# 32559   Married-civ-spouse     Exec-managerial         Wife   White   Female
#
#        Capital_gain  Capital_loss  Hours_per_week  Native_country  Income
# ...

# %% [markdown]
# in this we have last five rows of the dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32560 entries, 0 to 32559
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             32560 non-null  int64
#  1   Workclass       32560 non-null  object
#  2   Fnlwgt          32560 non-null  int64
#  3   Education       32560 non-null  object
#  4   Education_num   32560 non-null  int64
#  5   Marital_status  32560 non-null  object
#  6   Occupation      32560 non-null  object
#  7   Relationship    32560 non-null  object
#  8   Race            32560 non-null  object
#  9   Sex             32560 non-null  object
#  10  Capital_gain    32560 non-null  int64
#  11  Capital_loss    32560 non-null  int64
#  12  Hours_per_week  32560 non-null  int64
#  13  Native_country  32560 non-null  object
#  14  Income          32560 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %% [markdown]
# it gives us the information about our dataset.

# %%
df.skew()
# Out:
# Age                0.558738
# Fnlwgt             1.446972
# Education_num     -0.311630
# Capital_gain      11.953690
# Capital_loss       4.594549
# Hours_per_week     0.227636
# dtype: float64

# %% [markdown]
# it gives us the skewness of the dataset

# %%
df.shape
# Out:
# (32560, 15)

# %% [markdown]
# it gives us thde actual shape of our dataset having 32560 rows and 15 columns.

# %%
df.isnull().sum()
# Out:
# Age               0
# Workclass         0
# Fnlwgt            0
# Education         0
# Education_num     0
# Marital_status    0
# Occupation        0
# Relationship      0
# Race              0
# Sex               0
# Capital_gain      0
# Capital_loss      0
# Hours_per_week    0
# Native_country    0
# Income            0
# dtype: int64

# %% [markdown]
# we can see there is no null value present in our dataset

# %%
df.dtypes
# Out:
# Age                int64
# Workclass         object
# Fnlwgt             int64
# Education         object
# Education_num      int64
# Marital_status    object
# Occupation        object
# Relationship      object
# Race              object
# Sex               object
# Capital_gain       int64
# Capital_loss       int64
# Hours_per_week     int64
# Native_country    object
# Income            object
# dtype: object

# %% [markdown]
# in this we can see there are 9 object type features and 6 int64 type features

# %%
df.nunique()
# Out:
# Age                  73
# Workclass             9
# Fnlwgt            21647
# Education            16
# Education_num        16
# Marital_status        7
# Occupation           15
# Relationship          6
# Race                  5
# Sex                   2
# Capital_gain        119
# Capital_loss         92
# Hours_per_week       94
# Native_country       42
# Income                2
# dtype: int64

# %% [markdown]
# in this we can see the different-2 unique values of the columns present in the dataset.

# %%
df.describe()
# Out:
#                 Age        Fnlwgt  Education_num  Capital_gain  Capital_loss  \
# count  32560.000000  3.256000e+04   32560.000000  32560.000000  32560.000000
# mean      38.581634  1.897818e+05      10.080590   1077.615172     87.306511
# std       13.640642  1.055498e+05       2.572709   7385.402999    402.966116
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178315e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783630e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370545e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        Hours_per_week
# count    32560.000000
# mean        40.437469
# std         12.347618
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %% [markdown]
# This shows the brief description of our data having mean values, stsandard deviation, minimum and maximum values. For example Education_num has minimum value is 1 and maximum is 16 etc

# %%
df.columns
# Out:
# Index(['Age', 'Workclass', 'Fnlwgt', 'Education', 'Education_num',
#        'Marital_status', 'Occupation', 'Relationship', 'Race', 'Sex',
#        'Capital_gain', 'Capital_loss', 'Hours_per_week', 'Native_country',
#        'Income'],
#       dtype='object')

# %% [markdown]
# these are the column features of our dataset

# %%
df['Workclass'].value_counts()
# Out:
#  Private             22696
#  Self-emp-not-inc     2541
#  Local-gov            2093
#  ?                    1836
#  State-gov            1297
#  Self-emp-inc         1116
#  Federal-gov           960
#  Without-pay            14
#  Never-worked            7
# Name: Workclass, dtype: int64

# %% [markdown]
# in this we can see work class feature has subcategorical values like private has 22696, ? has 1836, state-gov has 1297 etc.

# %%
df['Occupation'].value_counts()
# Out:
#  Prof-specialty       4140
#  Craft-repair         4099
#  Exec-managerial      4066
#  Adm-clerical         3769
#  Sales                3650
#  Other-service        3295
#  Machine-op-inspct    2002
#  ?                    1843
#  Transport-moving     1597
#  Handlers-cleaners    1370
#  Farming-fishing       994
#  Tech-support          928
#  Protective-serv       649
#  Priv-house-serv       149
#  Armed-Forces            9
# Name: Occupation, dtype: int64

# %% [markdown]
# in this we can see occupation feature has subcategorical values like prof-speciality has 4140, ? has 1843, tech-support has 928 etc.

# %%
df['Native_country'].value_counts()
# Out:
#  United-States                 29169
#  Mexico                          643
#  ?                               583
#  Philippines                     198
#  Germany                         137
#  Canada                          121
#  Puerto-Rico                     114
#  El-Salvador                     106
#  India                           100
#  Cuba                             95
#  England                          90
#  Jamaica                          81
#  South                            80
#  China                            75
#  Italy                            73
#  Dominican-Republic               70
#  Vietnam                          67
#  Guatemala                        64
#  Japan                            62
#  Poland                           60
#  Columbia                         59
#  Taiwan                           51
#  Haiti                            44
#  Iran                             43
#  Portugal                         37
# ...

# %% [markdown]
# in this we can see the united states has the highest no. of occurance in country feature.and ? has 583 values

# %%
df['Marital_status'].value_counts()
# Out:
#  Married-civ-spouse       14976
#  Never-married            10682
#  Divorced                  4443
#  Separated                 1025
#  Widowed                    993
#  Married-spouse-absent      418
#  Married-AF-spouse           23
# Name: Marital_status, dtype: int64

# %% [markdown]
# this shows the no. of marital status values having category married-civ-spouse, divorced, widow, separated etc.

# %%
df['Sex'].value_counts()
# Out:
#  Male      21789
#  Female    10771
# Name: Sex, dtype: int64

# %% [markdown]
# no. of males is more as compared to females.

# %%
df['Education'].value_counts()
# Out:
#  HS-grad         10501
#  Some-college     7291
#  Bachelors        5354
#  Masters          1723
#  Assoc-voc        1382
#  11th             1175
#  Assoc-acdm       1067
#  10th              933
#  7th-8th           646
#  Prof-school       576
#  9th               514
#  12th              433
#  Doctorate         413
#  5th-6th           333
#  1st-4th           168
#  Preschool          51
# Name: Education, dtype: int64

# %% [markdown]
# this shows the no. of students who are in which standatd or which degree he or she has?

# %%
sns.countplot(df['Income'],palette='coolwarm',hue='Sex',data=df);

# %% [markdown]
# in this we can see there are approx 15000 no. of males and around 9000 females who are having salary <=50k

# %% [markdown]
# also we can see there are approx 6000 no. of males and around 1000 females who are having salary >50k

# %%
sns.countplot(df['Income'],palette='coolwarm',hue='Race',data=df);

# %% [markdown]
# in this we can see the race wise income of people <=50k and >50k

# %%
sns.countplot(df['Income'],palette='coolwarm',hue='Relationship',data=df);

# %% [markdown]
# this graph shows the realtionship wise income slab husband,wife,unmarried,own-child etc who are having salary <=50k and >50k

# %%
plt.subplots(figsize=(12,4))
sns.countplot(x='Income',hue='Native_country',data=df,palette='colorblind')
# Out:
# <AxesSubplot:xlabel='Income', ylabel='count'>

# %% [markdown]
# This shows the country wise income of the people with <=50k salary and >50k salary

# %%
sns.countplot(df['Income'])
# Out:
# <AxesSubplot:xlabel='Income', ylabel='count'>

# %% [markdown]
# in this we can see the there are arond 24000 people who are having <=50k salary and around 8000 people who are having >50k salary

# %%
df.replace(['None','Private'],inplace=True)
# Out:
# Age               None
# Workclass         None
# Fnlwgt            None
# Education         None
# Education_num     None
# Marital_status    None
# Occupation        None
# Relationship      None
# Race              None
# Sex               None
# Capital_gain      None
# Capital_loss      None
# Hours_per_week    None
# Native_country    None
# Income            None
# dtype: object

# %%
plt.subplots(figsize=(12,4))
sns.countplot(df['Workclass'])
# Out:
# <AxesSubplot:xlabel='Workclass', ylabel='count'>

# %% [markdown]
# this graph shows the class wise classification of income of people

# %%
plt.subplots(figsize=(12,4))
sns.countplot(df['Marital_status'])
# Out:
# <AxesSubplot:xlabel='Marital_status', ylabel='count'>

# %% [markdown]
# this graph shows the marital status of people

# %%
plt.subplots(figsize=(16,16))
sns.countplot(df['Education'])
# Out:
# <AxesSubplot:xlabel='Education', ylabel='count'>

# %% [markdown]
# this graph shows the education category wise slabs

# %%
plt.subplots(figsize=(16,16))
sns.countplot(df['Age'])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='count'>

# %% [markdown]
# this graph shows the age wise distribution of people.

# %%
plt.scatter(df['Education'],df['Education_num'])

# %% [markdown]
# the above graph shows the correlation between the education and education_num  is positive way.

# %%
plt.scatter(df['Capital_gain'],df['Hours_per_week'])

# %% [markdown]
# we can see the more is the hours per week more is the capital gain.

# %%
plt.scatter(df['Capital_loss'],df['Hours_per_week'])

# %% [markdown]
# this graph shows the if lesser is the hours per week more is the capital loss.

# %%
sns.pairplot(df)

# %% [markdown]
# This shows the correlation among the column features of the dataset.

# %%
df.head(15)
# Out:
#     Age          Workclass  Fnlwgt      Education  Education_num  \
# 0    50   Self-emp-not-inc   83311      Bachelors             13
# 1    38            Private  215646        HS-grad              9
# 2    53            Private  234721           11th              7
# 3    28            Private  338409      Bachelors             13
# 4    37            Private  284582        Masters             14
# 5    49            Private  160187            9th              5
# 6    52   Self-emp-not-inc  209642        HS-grad              9
# 7    31            Private   45781        Masters             14
# 8    42            Private  159449      Bachelors             13
# 9    37            Private  280464   Some-college             10
# 10   30          State-gov  141297      Bachelors             13
# 11   23            Private  122272      Bachelors             13
# 12   32            Private  205019     Assoc-acdm             12
# ...

# %%
df.corr()
# Out:
#                      Age    Fnlwgt  Education_num  Capital_gain  Capital_loss  \
# Age             1.000000 -0.076646       0.036527      0.077674      0.057775
# Fnlwgt         -0.076646  1.000000      -0.043159      0.000437     -0.010259
# Education_num   0.036527 -0.043159       1.000000      0.122627      0.079932
# Capital_gain    0.077674  0.000437       0.122627      1.000000     -0.031614
# Capital_loss    0.057775 -0.010259       0.079932     -0.031614      1.000000
# Hours_per_week  0.068756 -0.018770       0.148127      0.078409      0.054256
#
#                 Hours_per_week
# Age                   0.068756
# Fnlwgt               -0.018770
# Education_num         0.148127
# Capital_gain          0.078409
# Capital_loss          0.054256
# Hours_per_week        1.000000

# %% [markdown]
# these shows the correlation between the features. here we can see the age and fnlwgt also similar to each other

# %%
plt.subplots(figsize=(12,4))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
corr=df.corr()
plt.figure(figsize=(10,10))
sns.heatmap(corr,annot=True,cmap='BuPu')
# Out:
# <AxesSubplot:>

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder=LabelEncoder()
for column in df.columns:
    df[column]=labelencoder.fit_transform(df[column])

# %%
df
# Out:
#        Age  Workclass  Fnlwgt  Education  Education_num  Marital_status  \
# 0       33          6    2925          9             12               2
# 1       21          4   14085         11              8               0
# 2       36          4   15335          1              6               2
# 3       11          4   19354          9             12               2
# 4       20          4   17699         12             13               2
# ...    ...        ...     ...        ...            ...             ...
# 32555   10          4   16527          7             11               2
# 32556   23          4    8079         11              8               2
# 32557   41          4    7882         11              8               6
# 32558    5          4   12880         11              8               4
# 32559   35          5   17824         11              8               2
#
#        Occupation  Relationship  Race  Sex  Capital_gain  Capital_loss  \
# ...

# %%
from scipy.stats import zscore
z=np.abs(zscore(df))

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([    3,     7,     8, ..., 32550, 32552, 32559], dtype=int64), array([13, 10, 10, ...,  8,  8, 10], dtype=int64))

# %% [markdown]
# This shows the z score value when zscr>3 and threshold value is equal to 3.

# %%
z[32550][3]
# Out:
# 2.6608694681262763

# %% [markdown]
# this shows the z score value of 32550th row from the dataset when threshold value is 3.

# %%
df.skew()
# Out:
# Age               0.555583
# Workclass        -0.752280
# Fnlwgt            0.063137
# Education        -0.934063
# Education_num    -0.311630
# Marital_status   -0.013448
# Occupation        0.114540
# Relationship      0.786784
# Race             -2.435332
# Sex              -0.719244
# Capital_gain      3.572186
# Capital_loss      5.266058
# Hours_per_week    0.069753
# Native_country   -3.658235
# Income            1.212383
# dtype: float64

# %% [markdown]
# as we can noted  the  skewness of the redefined dataset

# %%
x=df.drop(columns=['Income'],axis=1)
y=df['Income']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
lg=LogisticRegression()
lg.fit(x_train,y_train)
pred=lg.predict(x_test)
print('accuracy score:',)
print(accuracy_score(y_test,pred))
print(confusion_matrix(y_test,pred))
print(classification_report(y_test,pred))
# Out:
# accuracy score:
# 0.8045454545454546
# [[5736  421]
#  [1170  813]]
#               precision    recall  f1-score   support
#
#            0       0.83      0.93      0.88      6157
#            1       0.66      0.41      0.51      1983
#
#     accuracy                           0.80      8140
#    macro avg       0.74      0.67      0.69      8140
# weighted avg       0.79      0.80      0.79      8140

# %% [markdown]
# in this we can say test accuracy is 80%

# %%
dt=DecisionTreeClassifier()
dt.fit(x_train,y_train)
pred=dt.predict(x_test)
print('accuracy score:',)
print(accuracy_score(y_test,pred))
print(confusion_matrix(y_test,pred))
print(classification_report(y_test,pred))
# Out:
# accuracy score:
# 0.8116707616707617
# [[5373  784]
#  [ 749 1234]]
#               precision    recall  f1-score   support
#
#            0       0.88      0.87      0.88      6157
#            1       0.61      0.62      0.62      1983
#
#     accuracy                           0.81      8140
#    macro avg       0.74      0.75      0.75      8140
# weighted avg       0.81      0.81      0.81      8140

# %% [markdown]
# in this test accuracy is 81%

# %%
gnb=GaussianNB()
gnb.fit(x_train,y_train)
predg=gnb.predict(x_test)
print('accuracy score:',)
print(accuracy_score(y_test,predg))
print(confusion_matrix(y_test,predg))
print(classification_report(y_test,predg))
# Out:
# accuracy score:
# 0.8234643734643735
# [[5746  411]
#  [1026  957]]
#               precision    recall  f1-score   support
#
#            0       0.85      0.93      0.89      6157
#            1       0.70      0.48      0.57      1983
#
#     accuracy                           0.82      8140
#    macro avg       0.77      0.71      0.73      8140
# weighted avg       0.81      0.82      0.81      8140

# %% [markdown]
# in this test accuracy is 82%

# %%
rf=RandomForestClassifier(n_estimators=100)
rf.fit(x_train,y_train)
pred=rf.predict(x_test)
print('accuracy score:',)
print(accuracy_score(y_test,pred))
print(confusion_matrix(y_test,pred))
print(classification_report(y_test,pred))
# Out:
# accuracy score:
# 0.8566339066339066
# [[5722  435]
#  [ 732 1251]]
#               precision    recall  f1-score   support
#
#            0       0.89      0.93      0.91      6157
#            1       0.74      0.63      0.68      1983
#
#     accuracy                           0.86      8140
#    macro avg       0.81      0.78      0.79      8140
# weighted avg       0.85      0.86      0.85      8140

# %% [markdown]
# in this test accuracy is 86%

# %%
sv=SVC()
sv.fit(x_train,y_train)
pred=sv.predict(x_test)
print('accuracy score:',)
print(accuracy_score(y_test,pred))
print(confusion_matrix(y_test,pred))
print(classification_report(y_test,pred))
# Out:
# accuracy score:
# 0.7563882063882064
# [[6157    0]
#  [1983    0]]
#               precision    recall  f1-score   support
#
#            0       0.76      1.00      0.86      6157
#            1       0.00      0.00      0.00      1983
#
#     accuracy                           0.76      8140
#    macro avg       0.38      0.50      0.43      8140
# weighted avg       0.57      0.76      0.65      8140

# %% [markdown]
# in this test accuracy is 76%

# %%
from sklearn.model_selection import cross_val_score
import joblib
import warnings
warnings.filterwarnings('ignore')

# %%
score=cross_val_score(sv,x,y,cv=5)
print(score)
print(score.mean())
# Out:
# [0.75921376 0.75921376 0.75921376 0.75921376 0.7590602 ]
# 0.7591830466830467

# %%
score=cross_val_score(gnb,x,y,cv=5)
print(score)
print(score.mean())
# Out:
# [0.81511057 0.81511057 0.82463145 0.81679975 0.82386364]
# 0.8191031941031941

# %%
score=cross_val_score(rf,x,y,cv=5)
print(score)
print(score.mean())
# Out:
# [0.85365479 0.85257985 0.85810811 0.86056511 0.86056511]
# 0.8570945945945946

# %%
score=cross_val_score(dt,x,y,cv=5)
print(score)
print(score.mean())
# Out:
# [0.80574324 0.80620393 0.80804668 0.8161855  0.80236486]
# 0.8077088452088452

# %%
score=cross_val_score(lg,x,y,cv=5)
print(score)
print(score.mean())
# Out:
# [0.78562654 0.79222973 0.79207617 0.79161548 0.79299754]
# 0.7909090909090909

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameter = {'max_depth': np.arange(2,10),
             'criterion':['gini','entropy']}

# %%
GCV=GridSearchCV(RandomForestClassifier(),parameter,cv=5)

# %%
GCV.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': array([2, 3, 4, 5, 6, 7, 8, 9])})

# %%
GCV.best_params_
# Out:
# {'criterion': 'gini', 'max_depth': 9}

# %%
joblib.dump(rf,'censusincomerf.obj')
# Out:
# ['censusincomerf.obj']

# %%
censusincomefile=joblib.load('censusincomerf.obj')
censusincomefile.predict(x_train)
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
model=[lg,sv,gnb,dt,rf]

for m in model:
    m.fit(x_train,y_train)
    pred=m.predict(x_test)
    print('accuracy score:',m)
    print(accuracy_score(y_test,pred))
    print(confusion_matrix(y_test,pred))
    print(classification_report(y_test,pred))
    score=cross_val_score(m,x,y,cv=5)
    print(score)
    print(score.mean())
# Out:
# accuracy score: LogisticRegression()
# 0.8045454545454546
# [[5736  421]
#  [1170  813]]
#               precision    recall  f1-score   support
#
#            0       0.83      0.93      0.88      6157
#            1       0.66      0.41      0.51      1983
#
#     accuracy                           0.80      8140
#    macro avg       0.74      0.67      0.69      8140
# weighted avg       0.79      0.80      0.79      8140
#
# [0.78562654 0.79222973 0.79207617 0.79161548 0.79299754]
# 0.7909090909090909
# accuracy score: SVC()
# 0.7563882063882064
# [[6157    0]
#  [1983    0]]
#               precision    recall  f1-score   support
#
#            0       0.76      1.00      0.86      6157
#            1       0.00      0.00      0.00      1983
#
#     accuracy                           0.76      8140
#    macro avg       0.38      0.50      0.43      8140
# weighted avg       0.57      0.76      0.65      8140
#
# [0.75921376 0.75921376 0.75921376 0.75921376 0.7590602 ]
# ...

# %% [markdown]
# in this we have different-2 test accuracy score which is given below:-
#     1. Logistic regression = 80%
#     2. SVC=76%
#     3. Naive byes Gaussian=82%
#     4. Decision tree classifier=81%
#     5. Random forest classifier=85%

# %%
joblib.dump(rf,'rfmodel.obj')
# Out:
# ['rfmodel.obj']

# %%
rffile=joblib.load('rfmodel.obj')
rffile.predict(x_train)
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %% [markdown]
# with confusion matrix we observed that our train and test data's having good accuracy score but we need to improve it. As we can see random forest classifier has the highest accuracy score 85% than all other classifier test.

# %% [markdown]
# So we choose it is our best model.
