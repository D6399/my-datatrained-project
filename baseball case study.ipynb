# %%
import pandas as pd 
import numpy as np

# %%
df=pd.read_csv('baseball.csv')
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %% [markdown]
# we have 30 rows and 17 columns in the data set

# %%
df.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %% [markdown]
# we have first 5 rows from the dataset

# %%
df.keys()
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %% [markdown]
# We have columns in the form of keys or features

# %%
df.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %% [markdown]
# we have 17 columns in our dataset

# %%
df.shape
# Out:
# (30, 17)

# %% [markdown]
# we have 30 rows and 17 columns in our dataset

# %%
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %% [markdown]
# there is no null values present in our dataset.

# %%
df.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %% [markdown]
# we can see all the columns are in int64. type except the ERA which is in float64 type

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %% [markdown]
# In this we can see small knowledge about our dataset including including non null values, memory usage and dtype values etc

# %%
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %% [markdown]
# in this we can see AB has the highest mean as compared to others. while W has 80.9666 mean value

# %%
df.W.unique()
# Out:
# array([ 95,  83,  81,  76,  74,  93,  87,  80,  78,  88,  86,  85,  68,
#        100,  98,  97,  64,  90,  71,  67,  63,  92,  84,  79], dtype=int64)

# %% [markdown]
# this shows the unique values occouring in 'W'

# %%
df.W.value_counts()
# Out:
# 68     3
# 81     2
# 74     2
# 76     2
# 83     2
# 80     1
# 97     1
# 98     1
# 67     1
# 71     1
# 78     1
# 79     1
# 95     1
# 100    1
# 92     1
# 84     1
# 85     1
# 86     1
# 87     1
# 88     1
# 90     1
# 63     1
# 93     1
# 64     1
# Name: W, dtype: int64

# %% [markdown]
# this shows the unique value counts in columns 'W'

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# we can see there is no missing value found all features lies around 0.00

# %%
df.skew()
# Out:
# W      0.047089
# R      1.200786
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# dtype: float64

# %% [markdown]
# these figures shows the skewness of different-2 values of columns.

# %%
df['R'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# we can see some outlier exists while plotting the 'R'

# %%
df['E'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# IN this we can see more than one outlier exist in 'E'. We have to remove it.

# %%
df['CG'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# there is no outlier exists in 'CG'

# %%
df.plot(kind='box',subplots=True,layout=(2,9))
# Out:
# W         AxesSubplot(0.125,0.536818;0.0731132x0.343182)
# R      AxesSubplot(0.212736,0.536818;0.0731132x0.343182)
# AB     AxesSubplot(0.300472,0.536818;0.0731132x0.343182)
# H      AxesSubplot(0.388208,0.536818;0.0731132x0.343182)
# 2B     AxesSubplot(0.475943,0.536818;0.0731132x0.343182)
# 3B     AxesSubplot(0.563679,0.536818;0.0731132x0.343182)
# HR     AxesSubplot(0.651415,0.536818;0.0731132x0.343182)
# BB     AxesSubplot(0.739151,0.536818;0.0731132x0.343182)
# SO     AxesSubplot(0.826887,0.536818;0.0731132x0.343182)
# SB           AxesSubplot(0.125,0.125;0.0731132x0.343182)
# RA        AxesSubplot(0.212736,0.125;0.0731132x0.343182)
# ER        AxesSubplot(0.300472,0.125;0.0731132x0.343182)
# ERA       AxesSubplot(0.388208,0.125;0.0731132x0.343182)
# CG        AxesSubplot(0.475943,0.125;0.0731132x0.343182)
# SHO       AxesSubplot(0.563679,0.125;0.0731132x0.343182)
# SV        AxesSubplot(0.651415,0.125;0.0731132x0.343182)
# ...

# %% [markdown]
# in this we can see some columns having outliers and some columns not. Now finally we have to remove it.

# %%
from scipy.stats import zscore
z=np.abs(zscore(df))

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([5], dtype=int64), array([1], dtype=int64))

# %% [markdown]
# This shows the z score value when zscr>3 and threshold value is equal to 3.

# %%
z[5][3]
# Out:
# 1.3610890420690174

# %% [markdown]
# this shows the z score value of 5 row from the dataset when threshold value is 3.

# %%
df.skew()
# Out:
# W      0.047089
# R      1.200786
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# dtype: float64

# %% [markdown]
# in this we can see the skewness of respectively columns.

# %%
df['R'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# in this we plot a histogram for 'R' to show the distribution of values from the dataset

# %%
df['E'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# in this we plot a histogram for 'E' to show the distribution of values from the dataset

# %%
df['CG'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# in this we plot a histogram for 'CG' to show the distribution of values from the dataset

# %%
from scipy.stats import boxcox

# %%
df['R']=boxcox(df['R'],0)

# %%
df['R']
# Out:
# 0     6.584791
# 1     6.545350
# 2     6.505784
# 3     6.432940
# 4     6.535241
# 5     6.792344
# 6     6.638568
# 7     6.569481
# 8     6.467699
# 9     6.617403
# 10    6.621406
# 11    6.591674
# 12    6.493754
# 13    6.486161
# 14    6.542472
# 15    6.472346
# 16    6.546785
# 17    6.535241
# 18    6.484635
# 19    6.461468
# 20    6.526495
# 21    6.555357
# 22    6.418365
# 23    6.350886
# 24    6.439350
# 25    6.502790
# 26    6.545350
# 27    6.579251
# 28    6.476972
# 29    6.602588
# Name: R, dtype: float64

# %% [markdown]
# IN this we are converting the 'R' data into a normal distribution.

# %%
plt.scatter(df['W'],df['R'])

# %% [markdown]
# in this we can see correlation between 'W' and 'R' and also the variable affected by each other.

# %%
plt.scatter(df['W'],df['SV'])

# %% [markdown]
# this also show the correlation between 'W' and 'SV'

# %%
sns.pairplot(df)

# %% [markdown]
# in this we can see grid of axes that each variable will be continuous or categorical.This pairplot shows the different-2 corrletion between variables occurs in the dataset.

# %%
corr_hmap=df.corr()
plt.figure(figsize=(10,8))
sns.heatmap(corr_hmap,annot=True)
plt.show()

# %% [markdown]
# It shows the correlation between the variables and the least correlating variable of 'ERA' is -0.82

# %%
plt.scatter(df['W'],df['E'])
plt.show()

# %% [markdown]
# this shows the how the variables of 'W' AND 'E' affected to each other.

# %%
df.drop('E',axis=1,inplace=True)

# %%
df.head()
# Out:
#     W         R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0  95  6.584791  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1  83  6.545350  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2  81  6.505784  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3  76  6.432940  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4  74  6.535241  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
#
#    SHO  SV
# 0    8  56
# 1   12  45
# 2   10  38
# 3    9  37
# 4   12  35

# %% [markdown]
# we have first 5 rows and 16 columns of our dataset

# %%
df_new=df[(z<3).all(axis=1)]

# %%
df.shape
# Out:
# (30, 16)

# %% [markdown]
# we have 30 rows  and 16 columns in our dataset.

# %%
df_new.shape
# Out:
# (29, 16)

# %% [markdown]
# in this we 29 rows and 16 columns in our dadaset

# %%
x=df.iloc[:,0:-1]
x.head()
# Out:
#     W         R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0  95  6.584791  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1  83  6.545350  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2  81  6.505784  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3  76  6.432940  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4  74  6.535241  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
#
#    SHO
# 0    8
# 1   12
# 2   10
# 3    9
# 4   12

# %% [markdown]
# After applying i loc function we have first 5 rows from the dataset.

# %%
y=df.iloc[:,-1]
y.head()
# Out:
# 0    56
# 1    45
# 2    38
# 3    37
# 4    35
# Name: SV, dtype: int64

# %% [markdown]
# in this we have first 5 values in the form of 'SV'

# %%
x.shape
# Out:
# (30, 15)

# %% [markdown]
# This shows we have 30 rows and 15 columns

# %%
y.shape
# Out:
# (30,)

# %% [markdown]
# this shows the 30 rows in the form of shape of y

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.33,random_state=42)

# %%
x_train.shape
# Out:
# (20, 15)

# %% [markdown]
# Now we have 20 columns and 15 rows.

# %%
y_train.shape
# Out:
# (20,)

# %% [markdown]
# in this we have 20 rows now.

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,mean_absolute_error
from sklearn.model_selection import train_test_split

# %%
lm = LinearRegression()

# %%
lm.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lm.coef_
# Out:
# array([ 6.36196549e-01, -3.00221817e+01,  6.57040919e-03, -1.95235356e-02,
#         8.28751260e-02, -4.66877332e-02, -5.43405348e-02,  2.65734642e-02,
#         2.31567247e-02, -4.23635583e-02, -2.57937056e-01,  4.43073519e-01,
#        -2.33972590e+01, -6.88766772e-01, -3.06294587e-01])

# %% [markdown]
# this shows the linear regression coefficient values comes in the form of array.

# %%
lm.intercept_
# Out:
# 121.4803460244062

# %% [markdown]
# linear regression intercept value is 121.48

# %%
df.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV'],
#       dtype='object')

# %% [markdown]
# this shows the columns present in our dataset.

# %%
lm.score(x_train,y_train)
# Out:
# 0.966037164691238

# %% [markdown]
# this shows the linear regression score is 96%

# %%
pred=lm.predict(x_test)
print("Predicted number of wins:",pred)
print("actual win",y_test)
# Out:
# Predicted number of wins: [42.50366471 56.52482692 37.1548843  50.84279432 48.09617081 37.9531988
#  37.95128656 38.17277235 43.57807423 45.13401627]
# actual win 27    44
# 15    62
# 23    44
# 17    48
# 8     60
# 9     40
# 28    41
# 24    35
# 12    46
# 0     56
# Name: SV, dtype: int64

# %% [markdown]
# this shows the prediction of the number of wins and actual no. of wins.

# %%
print('error:')
print('Mean absolute error:',mean_absolute_error(y_test,pred))
print('Mean squared error:',mean_squared_error(y_test,pred))
print('Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# error:
# Mean absolute error: 5.011944407188456
# Mean squared error: 37.63406374507984
# Root Mean Squared Error: 6.134660850045408

# %% [markdown]
# this shows the differnt-2 error values comes.

# %%
from sklearn.metrics import r2_score
print(r2_score(y_test,pred))
# Out:
# 0.4775948952654103

# %% [markdown]
# the r2 score is 47.75%

# %%
t=np.array([95,724,5575,1497,300,42,139,383,973,104,641,601,3.73,2,8,56,88])

# %%
t.shape
# Out:
# (17,)

# %%
t=t.reshape(1,-1)
t.shape
# Out:
# (1, 17)

# %%
lm.coef_
# Out:
# array([ 6.36196549e-01, -3.00221817e+01,  6.57040919e-03, -1.95235356e-02,
#         8.28751260e-02, -4.66877332e-02, -5.43405348e-02,  2.65734642e-02,
#         2.31567247e-02, -4.23635583e-02, -2.57937056e-01,  4.43073519e-01,
#        -2.33972590e+01, -6.88766772e-01, -3.06294587e-01])

# %%
pred=lm.predict(x_test)
print("Predicted number of wins:",pred)
print("actual win",y_test)
# Out:
# Predicted number of wins: [42.50366471 56.52482692 37.1548843  50.84279432 48.09617081 37.9531988
#  37.95128656 38.17277235 43.57807423 45.13401627]
# actual win 27    44
# 15    62
# 23    44
# 17    48
# 8     60
# 9     40
# 28    41
# 24    35
# 12    46
# 0     56
# Name: SV, dtype: int64

# %%
print('error:')
print(mean_squared_error(pred,y_test))
# Out:
# error:
# 37.63406374507984

# %%
from sklearn.linear_model import Lasso,Ridge

# %%
ls=Lasso(alpha=0.0001)
ls.fit(x_train,y_train)
ls.score(x_train,y_train)
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 13.382986011923718, tolerance: 0.07672000000000001
#   model = cd_fast.enet_coordinate_descent(
# 0.965316322755511

# %% [markdown]
# total score ias 96.53%

# %%
ls.coef_
# Out:
# array([ 6.97140894e-01, -3.58695023e+01,  1.44600730e-02, -2.27570804e-02,
#         8.28454719e-02, -5.78631048e-02, -4.99587684e-02,  2.80295668e-02,
#         2.27438635e-02, -3.75792604e-02, -2.41244322e-01,  3.27899819e-01,
#        -7.07786784e+00, -6.90724635e-01, -2.81401214e-01])

# %%
rd=Ridge(alpha=0.0001)
rd.fit(x_train,y_train)
rd.score(x_train,y_train)
# Out:
# 0.9660349166477528

# %% [markdown]
# in this total score is 96.60%

# %%
rd.coef_
# Out:
# array([ 6.37857813e-01, -2.99431350e+01,  6.96046541e-03, -1.98417015e-02,
#         8.26162859e-02, -4.78005564e-02, -5.47829169e-02,  2.65938751e-02,
#         2.32348386e-02, -4.21182207e-02, -2.57885992e-01,  4.39086074e-01,
#        -2.27430971e+01, -6.87132067e-01, -3.04180880e-01])

# %%
from sklearn.linear_model import ElasticNet
enr=ElasticNet(alpha=0.0001)
enr.fit(x_train,y_train)
enrpred=enr.predict(x_test)
print(enr.score(x_train,y_train))
enr.coef_
# Out:
# 0.9653480056052026
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 13.887391498517243, tolerance: 0.07672000000000001
#   model = cd_fast.enet_coordinate_descent(
# array([ 6.83885999e-01, -3.22467803e+01,  1.43272995e-02, -2.41342203e-02,
#         7.93523109e-02, -6.15457831e-02, -5.60207498e-02,  2.74559189e-02,
#         2.36919181e-02, -3.75293675e-02, -2.45873860e-01,  3.41996347e-01,
#        -8.67131127e+00, -6.72196229e-01, -2.73886305e-01])

# %% [markdown]
# in this total score is 96.53%

# %%
from sklearn.svm import SVR

svr=SVR(kernel='linear')
svr.fit(x_train,y_train)
svr.score(x_train,y_train)
pred_y=svr.predict(x_test)

svr=SVR(kernel='poly')
svr.fit(x_train,y_train)
svr.score(x_train,y_train)
pred_y=svr.predict(x_test)

svr=SVR(kernel='rbf')
svr.fit(x_train,y_train)
svr.score(x_train,y_train)
pred_y=svr.predict(x_test)

# %%
from sklearn.svm import SVR
kernellist=['linear','poly','rbf']
for i in kernellist:
    sv=SVR(kernel=i)
    sv.fit(x_train,y_train)
    print(sv.score(x_train,y_train))
# Out:
# 0.631784036076936
# 0.0011616576403721268
# -0.0009600040241237728

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.linear_model import Lasso

# %%
parameters={'alpha':[.0001,.001,.01,.1,1,10],'random_state':list(range(0,10))}
ls=Lasso()
clf=GridSearchCV(ls,parameters)
clf.fit(x_train,y_train)
print(clf.best_params_)
# Out:
# {'alpha': 10, 'random_state': 0}

# %%
ls=Lasso(alpha=0.01,random_state=0)
ls.fit(x_train,y_train)
ls.score(x_train,y_train)
pred_ls=ls.predict(x_test)
lss=r2_score(y_test,pred_ls)
lss
# Out:
# 0.30039689387007495

# %% [markdown]
# in this we can see r_2 score is 0.300396

# %%
cv_score=cross_val_score(ls,x,y,cv=5)
cv_mean=cv_score.mean()
cv_mean
# Out:
# -0.13733980436703885

# %% [markdown]
# when we check the cross validation mean values comes -0.13733

# %%
rd=Ridge(alpha=0.01,random_state=0)
rd.fit(x_train,y_train)
rd.score(x_train,y_train)
pred_rd=rd.predict(x_test)
rdd=r2_score(y_test,pred_rd)
rdd
# Out:
# 0.32992795832329824

# %% [markdown]
# the r_2 score value in ridge is 0.329927

# %%
cv_score=cross_val_score(rd,x,y,cv=5)
cv_mean=cv_score.mean()
cv_mean
# Out:
# -0.501867632646252

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor

parameters={'criterion':['mse','mae'],'max_features':['auto','sqrt','log2']}
rf=RandomForestRegressor()
clf=GridSearchCV(rf,parameters)
clf.fit(x_train,y_train)
print(clf.best_params_)
# Out:
# {'criterion': 'mae', 'max_features': 'log2'}

# %%
rf=RandomForestRegressor(criterion='mse',max_features='auto')
rf.fit(x_train,y_train)
rf.score(x_train,y_train)
pred_decision=rf.predict(x_test)

# %%
rfs=r2_score(y_test,pred_decision)
print('R2 Score:',rfs*100)
rfscore=cross_val_score(rf,x,y,cv=5)
rfc=rfscore.mean()
print('Cross Val Score:',rfc*100)
# Out:
# R2 Score: -28.133314825097177
# Cross Val Score: 7.82010287671507

# %%
from sklearn.ensemble import GradientBoostingRegressor

# %%
parameters={'criterion':['mse','mae'],'max_features':['auto','sqrt','log2']}
reg=GradientBoostingRegressor()
clf=GridSearchCV(reg,parameters)
clf.fit(x_train,y_train)
print(clf.best_params_)
# Out:
# {'criterion': 'mse', 'max_features': 'log2'}

# %%
rfs=r2_score(y_test,pred_decision)
print('R2 Score:',rfs*100)
rfscore=cross_val_score(rf,x,y,cv=5)
reg=rfscore.mean()
print('Cross Val Score:',rfc*100)
# Out:
# R2 Score: -28.133314825097177
# Cross Val Score: 7.82010287671507

# %%
import pickle
filename='baseball.pkl'
pickle.dump(rf,open(filename,'wb'))

# %%
loaded_model=pickle.load(open('baseball.pkl','rb'))
result=loaded_model.score(x_train,y_train)
print(result)
# Out:
# 0.8736672314911367

# %%
import pickle
filename='baseball.pkl'
pickle.dump(rd,open(filename,'wb'))

# %%
loaded_model=pickle.load(open('baseball.pkl','rb'))
result=loaded_model.score(x_train,y_train)
print(result)
# Out:
# 0.9615138521118581

# %%
import pickle
filename='baseball.pkl'
pickle.dump(ls,open(filename,'wb'))

# %%
loaded_model=pickle.load(open('baseball.pkl','rb'))
result=loaded_model.score(x_train,y_train)
print(result)
# Out:
# 0.9594107329756933

# %%
import pickle
filename='baseball.pkl'
pickle.dump(lm,open(filename,'wb'))

# %%
loaded_model=pickle.load(open('baseball.pkl','rb'))
result=loaded_model.score(x_train,y_train)
print(result)
# Out:
# 0.966037164691238

# %% [markdown]
# This model has the highest score so this is our best model having score 96.60%
