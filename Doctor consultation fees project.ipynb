# %%
import pandas as pd 
import numpy as np

# %%
test_df=pd.read_excel("C:\\Users\\HP\\Downloads\\Doctor_fee_consultation (1)\\Final Participant Data Folder\\Final_Test.xlsx")

# %%
test_df
# Out:
#                                         Qualification           Experience  \
# 0                                                MBBS  35 years experience
# 1          MBBS, Diploma in Otorhinolaryngology (DLO)  31 years experience
# 2                                          MBBS, DDVL  40 years experience
# 3                                                BAMS   0 years experience
# 4     BDS, MDS - Conservative Dentistry & Endodontics  16 years experience
# ...                                               ...                  ...
# 1982                         BAMS, Doctor of Medicine  10 years experience
# 1983   MD - Dermatology , Venereology & Leprosy, MBBS   4 years experience
# 1984         MBBS, MD / MS - Obstetrics & Gynaecology   9 years experience
# 1985                                              BDS  12 years experience
# 1986   MBBS, MD - Dermatology , Venereology & Leprosy   8 years experience
#
#      Rating                        Place           Profile  \
# ...

# %% [markdown]
# we have 1987 rows and 6 columns in test dataset

# %%
train_df=pd.read_excel("C:\\Users\\HP\\Downloads\\Doctor_fee_consultation (1)\\Final Participant Data Folder\\Final_Train.xlsx")

# %%
train_df
# Out:
#                        Qualification           Experience Rating  \
# 0              BHMS, MD - Homeopathy  24 years experience   100%
# 1       BAMS, MD - Ayurveda Medicine  12 years experience    98%
# 2     MBBS, MS - Otorhinolaryngology   9 years experience    NaN
# 3                BSc - Zoology, BAMS  12 years experience    NaN
# 4                               BAMS  20 years experience   100%
# ...                              ...                  ...    ...
# 5956                  MBBS, MS - ENT  19 years experience    98%
# 5957                            MBBS  33 years experience    NaN
# 5958                            MBBS  41 years experience    97%
# 5959     MBBS, MD - General Medicine  15 years experience    90%
# 5960         BDS, MDS - Orthodontics  17 years experience   100%
#
#                               Place           Profile  \
# 0               Kakkanad, Ernakulam         Homeopath
# 1             Whitefield, Bangalore          Ayurveda
# ...

# %% [markdown]
# we have 5961 rows and 7 columns in train dataset

# %%
test_df.shape
# Out:
# (1987, 6)

# %% [markdown]
# in this we have 1987 rows and 6 columns

# %%
train_df.shape
# Out:
# (5961, 7)

# %% [markdown]
# in this we have 5961 rows and 7 columns

# %%
test_df.dtypes
# Out:
# Qualification         object
# Experience            object
# Rating                object
# Place                 object
# Profile               object
# Miscellaneous_Info    object
# dtype: object

# %% [markdown]
# all the 6 columns are in object form.

# %%
train_df.dtypes
# Out:
# Qualification         object
# Experience            object
# Rating                object
# Place                 object
# Profile               object
# Miscellaneous_Info    object
# Fees                   int64
# dtype: object

# %% [markdown]
# in this we can see 6 columns are in object and one is int64

# %%
train_df.head(10)
# Out:
#                     Qualification           Experience Rating  \
# 0           BHMS, MD - Homeopathy  24 years experience   100%
# 1    BAMS, MD - Ayurveda Medicine  12 years experience    98%
# 2  MBBS, MS - Otorhinolaryngology   9 years experience    NaN
# 3             BSc - Zoology, BAMS  12 years experience    NaN
# 4                            BAMS  20 years experience   100%
# 5                            BAMS   8 years experience    NaN
# 6                            BHMS  42 years experience    NaN
# 7                             BDS  10 years experience    99%
# 8     MBBS, MD - General Medicine  14 years experience    NaN
# 9                        BSc, BDS  23 years experience    NaN
#
#                           Place           Profile  \
# 0           Kakkanad, Ernakulam         Homeopath
# 1         Whitefield, Bangalore          Ayurveda
# 2    Mathikere - BEL, Bangalore    ENT Specialist
# 3  Bannerghatta Road, Bangalore          Ayurveda
# ...

# %% [markdown]
# we have first 10 rows of train dataset

# %%
test_df.head(10)
# Out:
#                                        Qualification           Experience  \
# 0                                               MBBS  35 years experience
# 1         MBBS, Diploma in Otorhinolaryngology (DLO)  31 years experience
# 2                                         MBBS, DDVL  40 years experience
# 3                                               BAMS   0 years experience
# 4    BDS, MDS - Conservative Dentistry & Endodontics  16 years experience
# 5                                           BDS, MDS  14 years experience
# 6         MBBS, Diploma in Otorhinolaryngology (DLO)  23 years experience
# 7                             BDS, MDS - Pedodontics   9 years experience
# 8  MD - Ayurveda Medicine, BAMS, Yoga Teachers Tr...  11 years experience
# 9                                               BHMS  44 years experience
#
#   Rating                        Place           Profile  \
# 0    NaN       Ghatkopar East, Mumbai  General Medicine
# ...

# %% [markdown]
# in this we have first 10 rows of test dataset

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1987 entries, 0 to 1986
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Qualification       1987 non-null   object
#  1   Experience          1987 non-null   object
#  2   Rating              897 non-null    object
#  3   Place               1981 non-null   object
#  4   Profile             1987 non-null   object
#  5   Miscellaneous_Info  1153 non-null   object
# dtypes: object(6)
# memory usage: 93.3+ KB

# %% [markdown]
# Here we can see all the column features is in categorical form

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5961 entries, 0 to 5960
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Qualification       5961 non-null   object
#  1   Experience          5961 non-null   object
#  2   Rating              2659 non-null   object
#  3   Place               5936 non-null   object
#  4   Profile             5961 non-null   object
#  5   Miscellaneous_Info  3341 non-null   object
#  6   Fees                5961 non-null   int64
# dtypes: int64(1), object(6)
# memory usage: 326.1+ KB

# %% [markdown]
# in this we can see 5 column features is in categorical and 1 is integer form

# %%
test_df.describe()
# Out:
#        Qualification           Experience Rating                Place  \
# count           1987                 1987    897                 1981
# unique           630                   57     36                  592
# top             BAMS  10 years experience   100%  Mulund West, Mumbai
# freq             153                  110    223                   27
#
#                  Profile                                 Miscellaneous_Info
# count               1987                                               1153
# unique                 6                                               1084
# top     General Medicine  Acrylic Partial Denture Crowns and Bridges Fix...
# freq                 444                                                 10

# %% [markdown]
# it gives the brief description about our test dataset

# %%
train_df.describe()
# Out:
#               Fees
# count  5961.000000
# mean    307.944640
# std     190.920373
# min       5.000000
# 25%     150.000000
# 50%     300.000000
# 75%     500.000000
# max     950.000000

# %% [markdown]
# train dataset is having max. no. of count is 5961, max. fees 950 and min. is 5. mean value is 307.944

# %%
test_df.isnull().sum()
# Out:
# Qualification            0
# Experience               0
# Rating                1090
# Place                    6
# Profile                  0
# Miscellaneous_Info     834
# dtype: int64

# %% [markdown]
# there is some null values present in test_df dataset like rating has 1090, place has 6 and miscellaneous_info has 834.

# %%
train_df.isnull().sum()
# Out:
# Qualification            0
# Experience               0
# Rating                3302
# Place                   25
# Profile                  0
# Miscellaneous_Info    2620
# Fees                     0
# dtype: int64

# %% [markdown]
# as we can see there is some null values present in train_df dataset like rating has 3302, place has 25 and miscellaneous_info has 2620.

# %%
train_df['Rating'].fillna('0%', inplace=True)
test_df['Rating'].fillna('0%', inplace=True)

# %%
train_df['Miscellaneous_Info'].fillna('feedback', inplace=True)
test_df['Miscellaneous_Info'].fillna('feedback', inplace=True)

# %%
train_df['Place'].fillna('noida', inplace=True)
test_df['Place'].fillna('noida', inplace=True)

# %%
train_df
# Out:
#                        Qualification           Experience Rating  \
# 0              BHMS, MD - Homeopathy  24 years experience   100%
# 1       BAMS, MD - Ayurveda Medicine  12 years experience    98%
# 2     MBBS, MS - Otorhinolaryngology   9 years experience     0%
# 3                BSc - Zoology, BAMS  12 years experience     0%
# 4                               BAMS  20 years experience   100%
# ...                              ...                  ...    ...
# 5956                  MBBS, MS - ENT  19 years experience    98%
# 5957                            MBBS  33 years experience     0%
# 5958                            MBBS  41 years experience    97%
# 5959     MBBS, MD - General Medicine  15 years experience    90%
# 5960         BDS, MDS - Orthodontics  17 years experience   100%
#
#                               Place           Profile  \
# 0               Kakkanad, Ernakulam         Homeopath
# 1             Whitefield, Bangalore          Ayurveda
# ...

# %%
test_df
# Out:
#                                         Qualification           Experience  \
# 0                                                MBBS  35 years experience
# 1          MBBS, Diploma in Otorhinolaryngology (DLO)  31 years experience
# 2                                          MBBS, DDVL  40 years experience
# 3                                                BAMS   0 years experience
# 4     BDS, MDS - Conservative Dentistry & Endodontics  16 years experience
# ...                                               ...                  ...
# 1982                         BAMS, Doctor of Medicine  10 years experience
# 1983   MD - Dermatology , Venereology & Leprosy, MBBS   4 years experience
# 1984         MBBS, MD / MS - Obstetrics & Gynaecology   9 years experience
# 1985                                              BDS  12 years experience
# 1986   MBBS, MD - Dermatology , Venereology & Leprosy   8 years experience
#
#      Rating                        Place           Profile  \
# ...

# %% [markdown]
# we have removed the NaN values both from the train and test dataset

# %%
train_df.Qualification.unique()
# Out:
# array(['BHMS, MD - Homeopathy', 'BAMS, MD - Ayurveda Medicine',
#        'MBBS, MS - Otorhinolaryngology', ...,
#        'MD - Dermatology , Venereology & Leprosy, MBBS, Fellowship In Dermatosurgery',
#        'BDS, certification in smile designing',
#        'MD - Homeopathy, Post Graduate Diploma in Healthcare Management(PGDHM), DHMS (Diploma in Homeopathic Medicine and Surgery)'],
#       dtype=object)

# %% [markdown]
# these are the unique qualification values in train dataset

# %%
test_df.Qualification.unique()
# Out:
# array(['MBBS', 'MBBS, Diploma in Otorhinolaryngology (DLO)', 'MBBS, DDVL',
#        'BAMS', 'BDS, MDS - Conservative Dentistry & Endodontics',
#        'BDS, MDS', 'BDS, MDS - Pedodontics',
#        'MD - Ayurveda Medicine, BAMS, Yoga Teachers Training Course, M. D. IN KAYACHIKISTA',
#        'BHMS', 'BDS', 'MBBS, FCD - Diabetology', 'MBBS, DDV',
#        'MBBS, MD - Dermatology', 'MS - ENT',
#        'MBBS, Diploma in Otorhinolaryngology (DLO), MS - ENT, DNB - ENT, MNAMS (Membership of the National Academy)',
#        'BHMS, Diploma in Naturopathy & Yogic Science (DNYS), Diploma in Diet and Nutrition, Diploma in Cosmetology',
#        'MBBS, PG Diploma In Clinical Cosmetology (PGDCC)',
#        'BDS, MDS - Periodontics', 'BDS, MDS- Oral Pathology',
#        'MBBS, MD - General Medicine', 'MS - ENT, MBBS',
#        'MBBS, Diploma in Otorhinolaryngology (DLO), DNB - ENT',
#        'MBBS, MS - ENT, DNB - Otorhinolaryngology',
# ...

# %% [markdown]
# thses are the unique qualification values in test dataset

# %%
train_df.Qualification.value_counts()
# Out:
# BDS                                                                                                                                                                                    488
# BHMS                                                                                                                                                                                   477
# BAMS                                                                                                                                                                                   471
# MBBS                                                                                                                                                                                   334
# MBBS, MS - ENT                                                                                                                                                                         220
# ...

# %% [markdown]
# in this we can see there are 1420 qualification values in counting.

# %%
test_df.Qualification.value_counts()
# Out:
# BAMS                                                                                             153
# BHMS                                                                                             150
# BDS                                                                                              144
# MBBS                                                                                             107
# MBBS, MD - Dermatology                                                                            64
#                                                                                                 ...
# MBBS, Diploma in Anesthesiology, Certificate in Acupuncture                                        1
# MS - ENT, DNB - ENT, MBBS                                                                          1
# MD - Physician, FDIAB, Post Graduate Diploma in Diabetology (PGDD)                                 1
# ...

# %% [markdown]
# there are 630 qualification values counts in test dataset

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# %%
sns.heatmap(train_df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# we can see there is no missing value found all features lies around 0.00

# %%
sns.heatmap(test_df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# we can see there is no missing value found all features lies around 0.00

# %%
train_df_visualization_nominal=df[['Qualification','Experience','Rating','Place','Profile','Miscellaneous_Info']].copy()

# %%
train_df_visualization_nominal.columns
# Out:
# Index(['Qualification', 'Experience', 'Rating', 'Place', 'Profile',
#        'Miscellaneous_Info'],
#       dtype='object')

# %%
plt.figure(figsize=(24,22))
ax=sns.countplot(x='Qualification',data=train_df_visualization_nominal)
print(train_df_visualization_nominal['Qualification'].value_counts())
# Out:
# BAMS                                                                                             153
# BHMS                                                                                             150
# BDS                                                                                              144
# MBBS                                                                                             107
# MBBS, MD - Dermatology                                                                            64
#                                                                                                 ...
# MBBS, Diploma in Anesthesiology, Certificate in Acupuncture                                        1
# MS - ENT, DNB - ENT, MBBS                                                                          1
# MD - Physician, FDIAB, Post Graduate Diploma in Diabetology (PGDD)                                 1
# ...

# %% [markdown]
# this shows the no. of degree's of doctors

# %%
fig, ax = plt.subplots(figsize=(15, 7))
sns.countplot(train_df['Fees'].sort_values(), ax=ax, color='k', alpha=0.5)
plt.show()
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# this shows the fees structure charged by the doctors

# %%
plt.figure(figsize=(20,20))
ax=sns.countplot(x='Experience',data=train_df_visualization_nominal)
print(train_df_visualization_nominal['Experience'].value_counts())
# Out:
# 10 years experience    110
# 8 years experience      98
# 9 years experience      96
# 19 years experience     92
# 7 years experience      89
# 11 years experience     86
# 13 years experience     83
# 14 years experience     81
# 12 years experience     79
# 17 years experience     72
# 18 years experience     70
# 6 years experience      62
# 15 years experience     57
# 16 years experience     51
# 5 years experience      50
# 23 years experience     49
# 20 years experience     48
# 21 years experience     48
# 29 years experience     46
# 4 years experience      44
# 22 years experience     37
# 24 years experience     34
# 3 years experience      33
# 25 years experience     33
# 26 years experience     32
# 0 years experience      31
# 28 years experience     29
# 36 years experience     27
# 34 years experience     27
# 27 years experience     27
# 31 years experience     26
# 38 years experience     23
# 30 years experience     18
# 44 years experience     16
# ...

# %% [markdown]
# this shows the year wise no. of experince of doctors

# %%
plt.figure(figsize=(20,18))
ax=sns.countplot(x='Rating',data=train_df_visualization_nominal)
print(train_df_visualization_nominal['Rating'].value_counts())
# Out:
# 100%    223
# 98%     112
# 97%      84
# 99%      68
# 96%      65
# 94%      51
# 95%      47
# 93%      34
# 92%      29
# 90%      29
# 91%      26
# 88%      13
# 87%      11
# 89%      11
# 83%      11
# 82%       9
# 85%       8
# 80%       7
# 84%       7
# 71%       7
# 86%       6
# 73%       5
# 67%       5
# 70%       4
# 60%       4
# 76%       4
# 55%       3
# 81%       3
# 79%       2
# 69%       2
# 64%       2
# 78%       1
# 65%       1
# 52%       1
# 53%       1
# 77%       1
# Name: Rating, dtype: int64

# %% [markdown]
# this shows the % wise rating of doctors.

# %%
plt.figure(figsize=(20,18))
ax=sns.countplot(x='Place',data=train_df_visualization_nominal)
print(train_df_visualization_nominal['Place'].value_counts())
# Out:
# Mulund West, Mumbai             27
# Andheri West, Mumbai            27
# Dwarka, Delhi                   26
# Whitefield, Bangalore           23
# HSR Layout, Bangalore           22
#                                 ..
# Ayyappankavu, Ernakulam          1
# East Marredpally, Hyderabad      1
# Meerpet, Hyderabad               1
# Inder Puri, Delhi                1
# Karamana, Thiruvananthapuram     1
# Name: Place, Length: 592, dtype: int64

# %% [markdown]
# this shows the address wise information of hospital, clinic etc.

# %%
plt.figure(figsize=(10,8))
ax=sns.countplot(x='Profile',data=train_df_visualization_nominal)
print(train_df_visualization_nominal['Profile'].value_counts())
# Out:
# General Medicine    444
# Dentist             441
# Dermatologists      339
# Homeopath           277
# Ayurveda            251
# ENT Specialist      235
# Name: Profile, dtype: int64

# %% [markdown]
# this shows the profile wise presence of doctors as we see general medicine and dentist doctor's almost is same around 450 and ENT specialist and Ayurveda are having little bit differnce or we can say that almost  equal in no.'s

# %%
plt.figure(figsize=(20,18))
ax=sns.countplot(x='Miscellaneous_Info',data=train_df_visualization_nominal)
print(train_df_visualization_nominal['Miscellaneous_Info'].value_counts())
# Out:
# Acrylic Partial Denture Crowns and Bridges Fixing Artificial Teeth             10
# Skin Allergy Treatment Skin Allergies Dermabrasion                              9
# Dermabrasion Laser Resurfacing Acne / Pimples Treatment                         6
# Crowns and Bridges Fixing Complete/Partial Dentures Fixing Tooth Extraction     4
# Balance Exercises Acne / Pimples Treatment Insulin Treatment                    4
#                                                                                ..
# 98% 23 Feedback Mulanthuruthy, Ernakulam                                        1
# 98% 28 Feedback Kemps Corner, Mumbai                                            1
# 92% 14 Feedback Whitefield, Bangalore                                           1
# 92% 12 Feedback Rohini, Delhi                                                   1
# Varthur, Bangalore ₹100 Available Today                                         1
# Name: Miscellaneous_Info, Length: 1084, dtype: int64

# %% [markdown]
# in this we can see the miscellaneous_info like feedback from the respective customers.

# %%
test_df_visualization_nominal=df[['Qualification','Experience','Rating','Place','Profile','Miscellaneous_Info']].copy()

# %%
train_df_visualization_nominal.columns
# Out:
# Index(['Qualification', 'Experience', 'Rating', 'Place', 'Profile',
#        'Miscellaneous_Info'],
#       dtype='object')

# %%
plt.figure(figsize=(24,22))
ax=sns.countplot(x='Qualification',data=test_df_visualization_nominal)
print(test_df_visualization_nominal['Qualification'].value_counts())
# Out:
# BAMS                                                                                             153
# BHMS                                                                                             150
# BDS                                                                                              144
# MBBS                                                                                             107
# MBBS, MD - Dermatology                                                                            64
#                                                                                                 ...
# MBBS, Diploma in Anesthesiology, Certificate in Acupuncture                                        1
# MS - ENT, DNB - ENT, MBBS                                                                          1
# MD - Physician, FDIAB, Post Graduate Diploma in Diabetology (PGDD)                                 1
# ...

# %% [markdown]
# this shows the doctor's wise qualification from test dataset

# %%
plt.figure(figsize=(24,22))
ax=sns.countplot(x='Experience',data=test_df_visualization_nominal)
print(test_df_visualization_nominal['Experience'].value_counts())
# Out:
# 10 years experience    110
# 8 years experience      98
# 9 years experience      96
# 19 years experience     92
# 7 years experience      89
# 11 years experience     86
# 13 years experience     83
# 14 years experience     81
# 12 years experience     79
# 17 years experience     72
# 18 years experience     70
# 6 years experience      62
# 15 years experience     57
# 16 years experience     51
# 5 years experience      50
# 23 years experience     49
# 20 years experience     48
# 21 years experience     48
# 29 years experience     46
# 4 years experience      44
# 22 years experience     37
# 24 years experience     34
# 3 years experience      33
# 25 years experience     33
# 26 years experience     32
# 0 years experience      31
# 28 years experience     29
# 36 years experience     27
# 34 years experience     27
# 27 years experience     27
# 31 years experience     26
# 38 years experience     23
# 30 years experience     18
# 44 years experience     16
# ...

# %% [markdown]
# this shows the year wise experice of doctors from test data

# %%
plt.figure(figsize=(24,22))
ax=sns.countplot(x='Rating',data=test_df_visualization_nominal)
print(test_df_visualization_nominal['Rating'].value_counts())
# Out:
# 100%    223
# 98%     112
# 97%      84
# 99%      68
# 96%      65
# 94%      51
# 95%      47
# 93%      34
# 92%      29
# 90%      29
# 91%      26
# 88%      13
# 87%      11
# 89%      11
# 83%      11
# 82%       9
# 85%       8
# 80%       7
# 84%       7
# 71%       7
# 86%       6
# 73%       5
# 67%       5
# 70%       4
# 60%       4
# 76%       4
# 55%       3
# 81%       3
# 79%       2
# 69%       2
# 64%       2
# 78%       1
# 65%       1
# 52%       1
# 53%       1
# 77%       1
# Name: Rating, dtype: int64

# %% [markdown]
# this shows the % wise ratings of the doctors from the dataset

# %%
plt.figure(figsize=(10,8))
ax=sns.countplot(x='Profile',data=test_df_visualization_nominal)
print(test_df_visualization_nominal['Profile'].value_counts())
# Out:
# General Medicine    444
# Dentist             441
# Dermatologists      339
# Homeopath           277
# Ayurveda            251
# ENT Specialist      235
# Name: Profile, dtype: int64

# %% [markdown]
# this shows the profile wise presence of doctors as we see general medicine and dentist doctor's almost is same around 450 and ENT specialist and Ayurveda are having little bit differnce or we can say that almost equal in no.'s

# %%
plt.figure(figsize=(15,7))
ax=sns.countplot(x='Miscellaneous_Info',data=test_df_visualization_nominal,alpha=0.5)
print(test_df_visualization_nominal['Miscellaneous_Info'].value_counts())
# Out:
# Acrylic Partial Denture Crowns and Bridges Fixing Artificial Teeth             10
# Skin Allergy Treatment Skin Allergies Dermabrasion                              9
# Dermabrasion Laser Resurfacing Acne / Pimples Treatment                         6
# Crowns and Bridges Fixing Complete/Partial Dentures Fixing Tooth Extraction     4
# Balance Exercises Acne / Pimples Treatment Insulin Treatment                    4
#                                                                                ..
# 98% 23 Feedback Mulanthuruthy, Ernakulam                                        1
# 98% 28 Feedback Kemps Corner, Mumbai                                            1
# 92% 14 Feedback Whitefield, Bangalore                                           1
# 92% 12 Feedback Rohini, Delhi                                                   1
# Varthur, Bangalore ₹100 Available Today                                         1
# Name: Miscellaneous_Info, Length: 1084, dtype: int64

# %% [markdown]
# this shows the feedback etc  from the customers or patients.

# %%
sns.catplot(x='Experience', y='Fees', hue='Profile', data=train_df, height=4, aspect= 3)
plt.show()

# %% [markdown]
# this shows the profile wise experience doctros.

# %%
plt.scatter(train_df['Rating'],train_df['Experience'])

# %% [markdown]
# this graph shows the experince wise ratings of doctors.

# %%
plt.scatter(train_df['Qualification'],train_df['Rating'])

# %% [markdown]
# this graph shows the correlation between qualification and Rating.

# %%
plt.scatter(test_df['Rating'],test_df['Place'])

# %% [markdown]
# this shows the correlation between raing and place of test_df dataset.

# %%
plt.scatter(train_df['Rating'],train_df['Miscellaneous_Info'])

# %% [markdown]
# this shows the correlation between rating and miscellaneous_info of test_df

# %%
sns.pairplot(train_df)

# %% [markdown]
# above graph shows the correlation among the columns features of train_df dataset

# %%
sns.pairplot(test_df)

# %% [markdown]
# as we can see the correlation between column features of test_df dataset.

# %%
from sklearn.preprocessing import OrdinalEncoder
enc=OrdinalEncoder()

# %%
for i in df.columns:
    if train_df[i].dtypes=='object':
        train_df[i]=enc.fit_transform(train_df[i].values.reshape(-1,1))

# %%
train_df
# Out:
#       Qualification  Experience  Rating  Place  Profile  Miscellaneous_Info  \
# 0             401.0        16.0     1.0  299.0      5.0               130.0
# 1              73.0         3.0    50.0  866.0      0.0              1422.0
# 2            1135.0        63.0     0.0  457.0      3.0              2990.0
# 3             464.0         3.0     0.0   68.0      0.0              1695.0
# 4              10.0        12.0     1.0  337.0      0.0               253.0
# ...             ...         ...     ...    ...      ...                 ...
# 5956         1075.0        10.0    50.0   70.0      3.0              1385.0
# 5957          596.0        26.0     0.0  541.0      4.0              2990.0
# 5958          596.0        35.0    49.0  216.0      4.0              1173.0
# 5959          943.0         6.0    42.0  850.0      4.0              2202.0
# 5960          243.0         8.0     1.0  603.0      1.0              1595.0
#
#       Fees
# 0      100
# 1      350
# 2      300
# ...

# %%
from scipy.stats import zscore
z=np.abs(zscore(train_df))

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([ 275,  293,  987, 1314, 1631, 2165, 2252, 2393, 2428, 2522, 2623,
#        2708, 3365, 4040, 4581, 4730, 4835, 5195, 5250, 5311], dtype=int64), array([6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6],
#       dtype=int64))

# %% [markdown]
# This shows the z score value when zscr>3 and threshold value is equal to 3.

# %%
z[1314][3]
# Out:
# 0.2112235074141052

# %% [markdown]
# this shows the z score value of 1314th row from the dataset when threshold value is 3.

# %%
z[2393][3]
# Out:
# 0.29200454939946235

# %% [markdown]
# this shows the z score value of 2393th row from the dataset when threshold value is 3.

# %%
train_df.skew()
# Out:
# Qualification         0.239720
# Experience            0.823531
# Rating                0.814293
# Place                 0.116574
# Profile               0.108803
# Miscellaneous_Info   -0.825032
# Fees                  0.751870
# dtype: float64

# %% [markdown]
# this shows the skewness of the train_df dataset

# %%
for i in df.columns:
    if test_df[i].dtypes=='object':
        test_df[i]=enc.fit_transform(test_df[i].values.reshape(-1,1))

# %%
test_df
# Out:
#       Qualification  Experience  Rating  Place  Profile  Miscellaneous_Info
# 0             241.0        28.0     0.0  142.0      4.0              1083.0
# 1             340.0        24.0     0.0  580.0      3.0              1083.0
# 2             258.0        34.0    10.0  212.0      2.0               153.0
# 3               6.0         0.0     0.0  374.0      0.0              1083.0
# 4              79.0         7.0     1.0  231.0      1.0               816.0
# ...             ...         ...     ...    ...      ...                 ...
# 1982           17.0         1.0     0.0   58.0      0.0              1083.0
# 1983          548.0        33.0     0.0   96.0      2.0              1083.0
# 1984          474.0        56.0     0.0  424.0      4.0              1083.0
# 1985           51.0         3.0    35.0   26.0      1.0               975.0
# 1986          384.0        55.0     0.0  394.0      2.0                 9.0
#
# [1987 rows x 6 columns]

# %%
test_df.skew()
# Out:
# Qualification         0.280822
# Experience            0.687595
# Rating                0.843017
# Place                 0.043620
# Profile               0.028926
# Miscellaneous_Info   -0.752257
# dtype: float64

# %% [markdown]
# this shows the skewness of test_df dataset

# %%
from scipy.stats import zscore
z=np.abs(zscore(test_df))

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([], dtype=int64), array([], dtype=int64))

# %% [markdown]
# as we can see there is no z score value in test_df dataset

# %%
train_df.corr()
# Out:
#                     Qualification  Experience    Rating     Place   Profile  \
# Qualification            1.000000    0.003325  0.055170  0.006321  0.393123
# Experience               0.003325    1.000000 -0.139445 -0.009908 -0.032711
# Rating                   0.055170   -0.139445  1.000000 -0.038598 -0.102447
# Place                    0.006321   -0.009908 -0.038598  1.000000  0.016631
# Profile                  0.393123   -0.032711 -0.102447  0.016631  1.000000
# Miscellaneous_Info      -0.102695    0.042843 -0.476068  0.050013  0.019423
# Fees                     0.263214   -0.048529  0.143121 -0.063510  0.145226
#
#                     Miscellaneous_Info      Fees
# Qualification                -0.102695  0.263214
# Experience                    0.042843 -0.048529
# Rating                       -0.476068  0.143121
# Place                         0.050013 -0.063510
# Profile                       0.019423  0.145226
# Miscellaneous_Info            1.000000 -0.162495
# ...

# %% [markdown]
# this shows the correlation between features of train_df dataset

# %%
test_df.corr()
# Out:
#                     Qualification  Experience    Rating     Place   Profile  \
# Qualification            1.000000    0.018786  0.073823  0.020851  0.372002
# Experience               0.018786    1.000000 -0.163280 -0.008140  0.017496
# Rating                   0.073823   -0.163280  1.000000 -0.022797 -0.098592
# Place                    0.020851   -0.008140 -0.022797  1.000000 -0.005826
# Profile                  0.372002    0.017496 -0.098592 -0.005826  1.000000
# Miscellaneous_Info      -0.138608    0.071128 -0.470735  0.053442 -0.014365
#
#                     Miscellaneous_Info
# Qualification                -0.138608
# Experience                    0.071128
# Rating                       -0.470735
# Place                         0.053442
# Profile                      -0.014365
# Miscellaneous_Info            1.000000

# %% [markdown]
# this shows the correlation between features of test_df dataset

# %%
corr_hmap=train_df.corr()
plt.figure(figsize=(10,8))
sns.heatmap(corr_hmap,annot=True)
plt.show()

# %% [markdown]
# as we can see in the above graph miscellaneous_info and rating are highly negatively correlated with each other with value -0.48

# %%
corr_hmap=test_df.corr()
plt.figure(figsize=(10,8))
sns.heatmap(corr_hmap,annot=True)
plt.show()

# %% [markdown]
# Again we can see in the above graph miscellaneous_info and rating are highly negatively correlated with each other with value -0.47 in test_df dataset

# %%
x=train_df.iloc[:,0:-1]
x.head()
# Out:
#    Qualification  Experience  Rating  Place  Profile  Miscellaneous_Info
# 0          401.0        16.0     1.0  299.0      5.0               130.0
# 1           73.0         3.0    50.0  866.0      0.0              1422.0
# 2         1135.0        63.0     0.0  457.0      3.0              2990.0
# 3          464.0         3.0     0.0   68.0      0.0              1695.0
# 4           10.0        12.0     1.0  337.0      0.0               253.0

# %%
y=train_df.iloc[:,-1]
y.head()
# Out:
# 0    100
# 1    350
# 2    300
# 3    250
# 4    250
# Name: Fees, dtype: int64

# %%
x.shape
# Out:
# (5961, 6)

# %%
y.shape
# Out:
# (5961,)

# %%
from sklearn.preprocessing import MinMaxScaler
mms=MinMaxScaler()
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings('ignore')

# %%
for i in range(0,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=i)
    lr.fit(x_train,y_train)
    pred_train=lr.predict(x_train)
    pred_test=lr.predict(x_test)
    print(f'At random state{i},the training accuracy is:- {r2_score(y_train,pred_train)}')
    print(f'At random state{i},the testing accuracy is:- {r2_score(y_test,pred_test)}')
    print('\n')
# Out:
# At random state0,the training accuracy is:- 0.09435638101930943
# At random state0,the testing accuracy is:- 0.1277062471171686
#
#
# At random state1,the training accuracy is:- 0.10084917528454385
# At random state1,the testing accuracy is:- 0.10260339284648878
#
#
# At random state2,the training accuracy is:- 0.10257193126164688
# At random state2,the testing accuracy is:- 0.09550997351966584
#
#
# At random state3,the training accuracy is:- 0.10813413290746776
# At random state3,the testing accuracy is:- 0.07386611332612436
#
#
# At random state4,the training accuracy is:- 0.1054515286370723
# At random state4,the testing accuracy is:- 0.08495361642613253
#
#
# At random state5,the training accuracy is:- 0.10057426157251936
# At random state5,the testing accuracy is:- 0.10463463958491448
#
#
# At random state6,the training accuracy is:- 0.10015580457299356
# At random state6,the testing accuracy is:- 0.10200901605537238
#
#
# ...

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train.shape
# Out:
# (4768, 6)

# %%
y_train.shape
# Out:
# (4768,)

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
pred_test=lr.predict(x_test)

# %%
print(r2_score(y_test,pred_test))
# Out:
# 0.1040590773675586

# %%
train_accuracy=r2_score(y_train,pred_train)
test_accuracy=r2_score(y_test,pred_test)

from sklearn.model_selection import cross_val_score
for j in range(2,10):
    cv_score=cross_val_score(lr,x,y,cv=j)
    cv_mean=cv_score.mean()
    print(f'At cross fold {j} the cv score is {cv_mean} and accuracy score for traning is {train_accuracy} and accuracy for the testing is  {r2_score(y_test,pred_test)}')
    print('\n')
# Out:
# At cross fold 2 the cv score is 0.10055726689787647 and accuracy score for traning is -0.1048371785787543 and accuracy for the testing is  0.1040590773675586
#
#
# At cross fold 3 the cv score is 0.09954398170070818 and accuracy score for traning is -0.1048371785787543 and accuracy for the testing is  0.1040590773675586
#
#
# At cross fold 4 the cv score is 0.10010009807787534 and accuracy score for traning is -0.1048371785787543 and accuracy for the testing is  0.1040590773675586
#
#
# At cross fold 5 the cv score is 0.098548141376644 and accuracy score for traning is -0.1048371785787543 and accuracy for the testing is  0.1040590773675586
#
#
# At cross fold 6 the cv score is 0.09838801070532634 and accuracy score for traning is -0.1048371785787543 and accuracy for the testing is  0.1040590773675586
#
#
# At cross fold 7 the cv score is 0.09842317349807761 and accuracy score for traning is -0.1048371785787543 and accuracy for the testing is  0.1040590773675586
#
#
# ...

# %% [markdown]
# since the no. of folds  don't have much impact on the accuarcy

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor

parameters={'criterion':['mse','mae'],'max_features':['auto','sqrt','log2']}
rf=RandomForestRegressor()
clf=GridSearchCV(rf,parameters)
clf.fit(x_train,y_train)
print(clf.best_params_)
# Out:
# {'criterion': 'mae', 'max_features': 'sqrt'}

# %%
rf=RandomForestRegressor(criterion='mae',max_features='sqrt')
rf.fit(x_train,y_train)
rf.score(x_train,y_train)
pred_decision=rf.predict(x_test)

# %%
rfs=r2_score(y_test,pred_decision)
print('R2 Score:',rfs*100)
rfscore=cross_val_score(rf,x,y,cv=5)
rfc=rfscore.mean()
print('Cross Val Score:',rfc*100)
# Out:
# R2 Score: 18.55001192056579
# Cross Val Score: 17.407056339735096

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor

parameters={'criterion':['mse','mae'],'max_features':['auto','sqrt','log2']}
dt=DecisionTreeRegressor()
clf=GridSearchCV(dt,parameters)
clf.fit(x_train,y_train)
print(clf.best_params_)
# Out:
# {'criterion': 'mae', 'max_features': 'sqrt'}

# %%
dt=DecisionTreeRegressor(criterion='mae',max_features='sqrt')
dt.fit(x_train,y_train)
dt.score(x_train,y_train)
pred_decision=dt.predict(x_test)

# %%
dts=r2_score(y_test,pred_decision)
print('R2 Score:',dts*100)
dtscore=cross_val_score(rf,x,y,cv=5)
dtc=dtscore.mean()
print('Cross Val Score:',dtc*100)
# Out:
# R2 Score: -58.366297408001586
# Cross Val Score: 16.965507551215133

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR

parameters={'criterion':['mse','mae'],'max_features':['auto','sqrt','log2']}
sv=SVR()
clf=GridSearchCV(rf,parameters)
clf.fit(x_train,y_train)
print(clf.best_params_)
# Out:
# {'criterion': 'mae', 'max_features': 'sqrt'}

# %%
import pickle
filename='doctor consultation fees.pkl'
pickle.dump(rf,open(filename,'wb'))

# %%
loaded_model=pickle.load(open('doctor consultation fees.pkl','rb'))
result=loaded_model.score(x_train,y_train)
print(result)
# Out:
# 0.7464933283771411

# %% [markdown]
# the model score is 75%

# %%
import pickle
filename='doctor consultation fees.pkl'
pickle.dump(dt,open(filename,'wb'))

# %%
loaded_model=pickle.load(open('doctor consultation fees.pkl','rb'))
result=loaded_model.score(x_train,y_train)
print(result)
# Out:
# 0.9430459506124272

# %% [markdown]
# model score is 94%

# %%
import pickle
filename='doctor consultation fees.pkl'
pickle.dump(lr,open(filename,'wb'))

# %%
loaded_model=pickle.load(open('doctor consultation fees.pkl','rb'))
result=loaded_model.score(x_train,y_train)
print(result)
# Out:
# 0.10079480751679959

# %% [markdown]
# the model score is 100%

# %% [markdown]
# as we can see the our train and test data are balanced linear regression score is 100% and decision tree regressor test score also comes with 94%

# %% [markdown]
# lineargression is our best model
