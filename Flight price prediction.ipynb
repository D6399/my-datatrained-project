# %%
import pandas as pd
import numpy as np

# %%
train_df=pd.read_excel("C:\\Users\\HP\Downloads\\Flight_Ticket_Participant_Datasets-20190305T100527Z-001\\Flight_Ticket_Participant_Datasets\\Data_Train.xlsx")

# %%
train_df
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi
# 1        Air India       1/05/2019   Kolkata    Banglore
# 2      Jet Airways       9/06/2019     Delhi      Cochin
# 3           IndiGo      12/05/2019   Kolkata    Banglore
# 4           IndiGo      01/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                  BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1      CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# ...

# %% [markdown]
# inn this we have 10683 rows and 11 columns

# %%
test_df=pd.read_excel("C:\\Users\\HP\\Downloads\\Flight_Ticket_Participant_Datasets-20190305T100527Z-001\\Flight_Ticket_Participant_Datasets\\Test_set.xlsx")

# %%
test_df
# Out:
#                 Airline Date_of_Journey    Source Destination  \
# 0           Jet Airways       6/06/2019     Delhi      Cochin
# 1                IndiGo      12/05/2019   Kolkata    Banglore
# 2           Jet Airways      21/05/2019     Delhi      Cochin
# 3     Multiple carriers      21/05/2019     Delhi      Cochin
# 4              Air Asia      24/06/2019  Banglore       Delhi
# ...                 ...             ...       ...         ...
# 2666          Air India       6/06/2019   Kolkata    Banglore
# 2667             IndiGo      27/03/2019   Kolkata    Banglore
# 2668        Jet Airways       6/03/2019     Delhi      Cochin
# 2669          Air India       6/03/2019     Delhi      Cochin
# 2670  Multiple carriers      15/06/2019     Delhi      Cochin
#
#                 Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0     DEL → BOM → COK    17:30  04:25 07 Jun  10h 55m      1 stop
# 1     CCU → MAA → BLR    06:20         10:20       4h      1 stop
# ...

# %% [markdown]
# we have 2671 rows and 10 columns

# %%
train_df.head(10)
# Out:
#              Airline Date_of_Journey    Source Destination  \
# 0             IndiGo      24/03/2019  Banglore   New Delhi
# 1          Air India       1/05/2019   Kolkata    Banglore
# 2        Jet Airways       9/06/2019     Delhi      Cochin
# 3             IndiGo      12/05/2019   Kolkata    Banglore
# 4             IndiGo      01/03/2019  Banglore   New Delhi
# 5           SpiceJet      24/06/2019   Kolkata    Banglore
# 6        Jet Airways      12/03/2019  Banglore   New Delhi
# 7        Jet Airways      01/03/2019  Banglore   New Delhi
# 8        Jet Airways      12/03/2019  Banglore   New Delhi
# 9  Multiple carriers      27/05/2019     Delhi      Cochin
#
#                    Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0              BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1  CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# 2  DEL → LKO → BOM → COK    09:25  04:25 10 Jun      19h     2 stops
# ...

# %% [markdown]
# we have first 10 rows of train dataset

# %%
test_df.head(10)
# Out:
#              Airline Date_of_Journey    Source Destination            Route  \
# 0        Jet Airways       6/06/2019     Delhi      Cochin  DEL → BOM → COK
# 1             IndiGo      12/05/2019   Kolkata    Banglore  CCU → MAA → BLR
# 2        Jet Airways      21/05/2019     Delhi      Cochin  DEL → BOM → COK
# 3  Multiple carriers      21/05/2019     Delhi      Cochin  DEL → BOM → COK
# 4           Air Asia      24/06/2019  Banglore       Delhi        BLR → DEL
# 5        Jet Airways      12/06/2019     Delhi      Cochin  DEL → BOM → COK
# 6          Air India      12/03/2019  Banglore   New Delhi  BLR → TRV → DEL
# 7             IndiGo       1/05/2019   Kolkata    Banglore  CCU → HYD → BLR
# 8             IndiGo      15/03/2019   Kolkata    Banglore        CCU → BLR
# 9        Jet Airways      18/05/2019   Kolkata    Banglore  CCU → BOM → BLR
#
#   Dep_Time  Arrival_Time Duration Total_Stops              Additional_Info
# ...

# %% [markdown]
# we have first 10 rows of test dataset

# %%
train_df.shape
# Out:
# (10683, 11)

# %% [markdown]
# we have 10683 rows and 11 columns

# %%
test_df.shape
# Out:
# (2671, 10)

# %% [markdown]
# we have 2671 rows and 10 columns

# %%
test_df.dtypes
# Out:
# Airline            object
# Date_of_Journey    object
# Source             object
# Destination        object
# Route              object
# Dep_Time           object
# Arrival_Time       object
# Duration           object
# Total_Stops        object
# Additional_Info    object
# dtype: object

# %% [markdown]
# all the 10 columns are in categorical or in object form

# %%
train_df.dtypes
# Out:
# Airline            object
# Date_of_Journey    object
# Source             object
# Destination        object
# Route              object
# Dep_Time           object
# Arrival_Time       object
# Duration           object
# Total_Stops        object
# Additional_Info    object
# Price               int64
# dtype: object

# %% [markdown]
# all the 10 coumns in categorical and 1 column is in integer form.

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2671 entries, 0 to 2670
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          2671 non-null   object
#  1   Date_of_Journey  2671 non-null   object
#  2   Source           2671 non-null   object
#  3   Destination      2671 non-null   object
#  4   Route            2671 non-null   object
#  5   Dep_Time         2671 non-null   object
#  6   Arrival_Time     2671 non-null   object
#  7   Duration         2671 non-null   object
#  8   Total_Stops      2671 non-null   object
#  9   Additional_Info  2671 non-null   object
# dtypes: object(10)
# memory usage: 208.8+ KB

# %% [markdown]
# all the column features are in categorical form

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Date_of_Journey  10683 non-null  object
#  2   Source           10683 non-null  object
#  3   Destination      10683 non-null  object
#  4   Route            10682 non-null  object
#  5   Dep_Time         10683 non-null  object
#  6   Arrival_Time     10683 non-null  object
#  7   Duration         10683 non-null  object
#  8   Total_Stops      10682 non-null  object
#  9   Additional_Info  10683 non-null  object
#  10  Price            10683 non-null  int64
# dtypes: int64(1), object(10)
# memory usage: 918.2+ KB

# %% [markdown]
# in this we can see 10 columns are in categorical and 1 is in integer type.

# %%
test_df.describe()
# Out:
#             Airline Date_of_Journey Source Destination            Route  \
# count          2671            2671   2671        2671             2671
# unique           11              44      5           6              100
# top     Jet Airways       9/05/2019  Delhi      Cochin  DEL → BOM → COK
# freq            897             144   1145        1145              624
#
#        Dep_Time Arrival_Time Duration Total_Stops Additional_Info
# count      2671         2671     2671        2671            2671
# unique      199          704      320           5               6
# top       10:00        19:00   2h 50m      1 stop         No info
# freq         62          113      122        1431            2148

# %% [markdown]
# it gives the brief description about our test dataset unque values, top ranking airline frequecncy of the airline etc.

# %%
train_df.describe()
# Out:
#               Price
# count  10683.000000
# mean    9087.064121
# std     4611.359167
# min     1759.000000
# 25%     5277.000000
# 50%     8372.000000
# 75%    12373.000000
# max    79512.000000

# %% [markdown]
# it gives the mean, standard deviation value, minimum and maximum value of the train dataset

# %%
test_df.isnull().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              0
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        0
# Additional_Info    0
# dtype: int64

# %% [markdown]
# there is no null value present in test dataset

# %%
train_df.isnull().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              1
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        1
# Additional_Info    0
# Price              0
# dtype: int64

# %% [markdown]
# there is some null value present in our train dataset like route has 1 and total_stops has 1 missing value.

# %%
train_df.dropna(inplace=True)

# %%
train_df.isnull().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              0
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        0
# Additional_Info    0
# Price              0
# dtype: int64

# %% [markdown]
# now there is no missing value present in our train dataset.

# %%
train_df
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi
# 1        Air India       1/05/2019   Kolkata    Banglore
# 2      Jet Airways       9/06/2019     Delhi      Cochin
# 3           IndiGo      12/05/2019   Kolkata    Banglore
# 4           IndiGo      01/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                  BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1      CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# ...

# %%
train_df.shape
# Out:
# (10682, 11)

# %% [markdown]
# we have 10682 rows and 11 columns now

# %%
train_df['Duration'].value_counts()
# Out:
# 2h 50m     550
# 1h 30m     386
# 2h 45m     337
# 2h 55m     337
# 2h 35m     329
#           ...
# 30h 25m      1
# 5m           1
# 47h 40m      1
# 33h 45m      1
# 37h 10m      1
# Name: Duration, Length: 368, dtype: int64

# %% [markdown]
# in this we can see the time taking duration of the flights.

# %%
train_df['Journey_day']=pd.to_datetime(train_df.Date_of_Journey,format='%d/%m/%Y').dt.day

# %%
train_df['Journey_month']=pd.to_datetime(train_df.Date_of_Journey,format='%d/%m/%Y').dt.month

# %%
train_df.head(10)
# Out:
#              Airline Date_of_Journey    Source Destination  \
# 0             IndiGo      24/03/2019  Banglore   New Delhi
# 1          Air India       1/05/2019   Kolkata    Banglore
# 2        Jet Airways       9/06/2019     Delhi      Cochin
# 3             IndiGo      12/05/2019   Kolkata    Banglore
# 4             IndiGo      01/03/2019  Banglore   New Delhi
# 5           SpiceJet      24/06/2019   Kolkata    Banglore
# 6        Jet Airways      12/03/2019  Banglore   New Delhi
# 7        Jet Airways      01/03/2019  Banglore   New Delhi
# 8        Jet Airways      12/03/2019  Banglore   New Delhi
# 9  Multiple carriers      27/05/2019     Delhi      Cochin
#
#                    Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0              BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1  CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# 2  DEL → LKO → BOM → COK    09:25  04:25 10 Jun      19h     2 stops
# ...

# %% [markdown]
# we have added 2 columns in our train data set

# %%
train_df.shape
# Out:
# (10682, 13)

# %% [markdown]
# 2 more columns added so we have 10682 rows and 13 columns now

# %%
train_df.drop(['Date_of_Journey'],axis=1,inplace=True)

# %%
train_df['Dep_hour']=pd.to_datetime(train_df['Dep_Time']).dt.hour

# %%
train_df['Dep_min']=pd.to_datetime(train_df['Dep_Time']).dt.minute

# %%
train_df.drop(['Dep_Time'],axis=1,inplace=True)

# %%
train_df.head(10)
# Out:
#              Airline    Source Destination                  Route  \
# 0             IndiGo  Banglore   New Delhi              BLR → DEL
# 1          Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2        Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK
# 3             IndiGo   Kolkata    Banglore        CCU → NAG → BLR
# 4             IndiGo  Banglore   New Delhi        BLR → NAG → DEL
# 5           SpiceJet   Kolkata    Banglore              CCU → BLR
# 6        Jet Airways  Banglore   New Delhi        BLR → BOM → DEL
# 7        Jet Airways  Banglore   New Delhi        BLR → BOM → DEL
# 8        Jet Airways  Banglore   New Delhi        BLR → BOM → DEL
# 9  Multiple carriers     Delhi      Cochin        DEL → BOM → COK
#
#    Arrival_Time Duration Total_Stops              Additional_Info  Price  \
# 0  01:10 22 Mar   2h 50m    non-stop                      No info   3897
# 1         13:15   7h 25m     2 stops                      No info   7662
# ...

# %%
train_df['Arrival_hour']=pd.to_datetime(train_df['Arrival_Time']).dt.hour

# %%
train_df['Arrival_min']=pd.to_datetime(train_df['Arrival_Time']).dt.minute

# %%
train_df.drop(['Arrival_Time'],axis=1,inplace=True)

# %%
train_df.head(10)
# Out:
#              Airline    Source Destination                  Route Duration  \
# 0             IndiGo  Banglore   New Delhi              BLR → DEL   2h 50m
# 1          Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR   7h 25m
# 2        Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK      19h
# 3             IndiGo   Kolkata    Banglore        CCU → NAG → BLR   5h 25m
# 4             IndiGo  Banglore   New Delhi        BLR → NAG → DEL   4h 45m
# 5           SpiceJet   Kolkata    Banglore              CCU → BLR   2h 25m
# 6        Jet Airways  Banglore   New Delhi        BLR → BOM → DEL  15h 30m
# 7        Jet Airways  Banglore   New Delhi        BLR → BOM → DEL   21h 5m
# 8        Jet Airways  Banglore   New Delhi        BLR → BOM → DEL  25h 30m
# 9  Multiple carriers     Delhi      Cochin        DEL → BOM → COK   7h 50m
#
#   Total_Stops              Additional_Info  Price  Journey_day  Journey_month  \
# ...

# %% [markdown]
# in this we have added 2 column features like arrival_hour and arrival_min.

# %%
duration=list(train_df['Duration'])

for i in range (len(duration)):
    if len(duration[i].split()) !=2:
        if 'h' in duration[i]:
            duration[i]=duration[i].strip() + '0m'
        else:
            duration[i]='0h' + duration[i]

# %%
duration_hours=[]
duration_mins=[]
for i in range (len(duration)):
    duration_hours.append(int(duration[i].split(sep='h')[0]))

# %%
train_df.drop(['Duration'],axis=1,inplace=True)

# %%
train_df.head()
# Out:
#        Airline    Source Destination                  Route Total_Stops  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL    non-stop
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR     2 stops
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK     2 stops
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR      1 stop
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL      1 stop
#
#   Additional_Info  Price  Journey_day  Journey_month  Dep_hour  Dep_min  \
# 0         No info   3897           24              3        22       20
# 1         No info   7662            1              5         5       50
# 2         No info  13882            9              6         9       25
# 3         No info   6218           12              5        18        5
# 4         No info  13302            1              3        16       50
#
#    Arrival_hour  Arrival_min
# 0             1           10
# 1            13           15
# ...

# %%
train_df['Airline'].value_counts()
# Out:
# Jet Airways                          3849
# IndiGo                               2053
# Air India                            1751
# Multiple carriers                    1196
# SpiceJet                              818
# Vistara                               479
# Air Asia                              319
# GoAir                                 194
# Multiple carriers Premium economy      13
# Jet Airways Business                    6
# Vistara Premium economy                 3
# Trujet                                  1
# Name: Airline, dtype: int64

# %% [markdown]
# thias shows the no. of value counts Airline column

# %%
test_df
# Out:
#                 Airline Date_of_Journey    Source Destination  \
# 0           Jet Airways       6/06/2019     Delhi      Cochin
# 1                IndiGo      12/05/2019   Kolkata    Banglore
# 2           Jet Airways      21/05/2019     Delhi      Cochin
# 3     Multiple carriers      21/05/2019     Delhi      Cochin
# 4              Air Asia      24/06/2019  Banglore       Delhi
# ...                 ...             ...       ...         ...
# 2666          Air India       6/06/2019   Kolkata    Banglore
# 2667             IndiGo      27/03/2019   Kolkata    Banglore
# 2668        Jet Airways       6/03/2019     Delhi      Cochin
# 2669          Air India       6/03/2019     Delhi      Cochin
# 2670  Multiple carriers      15/06/2019     Delhi      Cochin
#
#                 Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0     DEL → BOM → COK    17:30  04:25 07 Jun  10h 55m      1 stop
# 1     CCU → MAA → BLR    06:20         10:20       4h      1 stop
# ...

# %%
test_df.shape
# Out:
# (2671, 10)

# %% [markdown]
# we have 2671 rows and 10 columns

# %%
test_df['Duration'].value_counts()
# Out:
# 2h 50m     122
# 1h 30m     107
# 2h 45m      95
# 2h 55m      81
# 3h          72
#           ...
# 32h 25m      1
# 20h 25m      1
# 17h 30m      1
# 19h 45m      1
# 32h 5m       1
# Name: Duration, Length: 320, dtype: int64

# %% [markdown]
# this shows the no. of valu counts of Duration column from test dataset

# %%
test_df['Journey_day']=pd.to_datetime(test_df.Date_of_Journey,format='%d/%m/%Y').dt.day

# %%
test_df['Journey_month']=pd.to_datetime(test_df.Date_of_Journey,format='%d/%m/%Y').dt.month

# %%
test_df.head()
# Out:
#              Airline Date_of_Journey    Source Destination            Route  \
# 0        Jet Airways       6/06/2019     Delhi      Cochin  DEL → BOM → COK
# 1             IndiGo      12/05/2019   Kolkata    Banglore  CCU → MAA → BLR
# 2        Jet Airways      21/05/2019     Delhi      Cochin  DEL → BOM → COK
# 3  Multiple carriers      21/05/2019     Delhi      Cochin  DEL → BOM → COK
# 4           Air Asia      24/06/2019  Banglore       Delhi        BLR → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops              Additional_Info  \
# 0    17:30  04:25 07 Jun  10h 55m      1 stop                      No info
# 1    06:20         10:20       4h      1 stop                      No info
# 2    19:15  19:00 22 May  23h 45m      1 stop  In-flight meal not included
# 3    08:00         21:00      13h      1 stop                      No info
# 4    23:55  02:45 25 Jun   2h 50m    non-stop                      No info
#
#    Journey_day  Journey_month
# ...

# %% [markdown]
# we have added 2 more columns in our test dataset

# %%
test_df.shape
# Out:
# (2671, 12)

# %% [markdown]
# we have 2671 rows and 12 columns right now.

# %%
test_df.drop(['Date_of_Journey'],axis=1,inplace=True)

# %%
test_df['Dep_hour']=pd.to_datetime(test_df['Dep_Time']).dt.hour

# %%
test_df['Dep_min']=pd.to_datetime(test_df['Dep_Time']).dt.minute

# %%
test_df.drop(['Dep_Time'],axis=1,inplace=True)

# %%
test_df.head(10)
# Out:
#              Airline    Source Destination            Route  Arrival_Time  \
# 0        Jet Airways     Delhi      Cochin  DEL → BOM → COK  04:25 07 Jun
# 1             IndiGo   Kolkata    Banglore  CCU → MAA → BLR         10:20
# 2        Jet Airways     Delhi      Cochin  DEL → BOM → COK  19:00 22 May
# 3  Multiple carriers     Delhi      Cochin  DEL → BOM → COK         21:00
# 4           Air Asia  Banglore       Delhi        BLR → DEL  02:45 25 Jun
# 5        Jet Airways     Delhi      Cochin  DEL → BOM → COK  12:35 13 Jun
# 6          Air India  Banglore   New Delhi  BLR → TRV → DEL         22:35
# 7             IndiGo   Kolkata    Banglore  CCU → HYD → BLR         20:30
# 8             IndiGo   Kolkata    Banglore        CCU → BLR         12:55
# 9        Jet Airways   Kolkata    Banglore  CCU → BOM → BLR         22:35
#
#   Duration Total_Stops              Additional_Info  Journey_day  \
# 0  10h 55m      1 stop                      No info            6
# ...

# %%
test_df.shape
# Out:
# (2671, 12)

# %% [markdown]
# we have removed dep_time and date_of_journey from the test dataset.

# %%
test_df['Arrival_hour']=pd.to_datetime(test_df['Arrival_Time']).dt.hour

# %%
test_df['Arrival_min']=pd.to_datetime(test_df['Arrival_Time']).dt.minute

# %%
test_df.drop(['Arrival_Time'],axis=1,inplace=True)

# %%
test_df.head()
# Out:
#              Airline    Source Destination            Route Duration  \
# 0        Jet Airways     Delhi      Cochin  DEL → BOM → COK  10h 55m
# 1             IndiGo   Kolkata    Banglore  CCU → MAA → BLR       4h
# 2        Jet Airways     Delhi      Cochin  DEL → BOM → COK  23h 45m
# 3  Multiple carriers     Delhi      Cochin  DEL → BOM → COK      13h
# 4           Air Asia  Banglore       Delhi        BLR → DEL   2h 50m
#
#   Total_Stops              Additional_Info  Journey_day  Journey_month  \
# 0      1 stop                      No info            6              6
# 1      1 stop                      No info           12              5
# 2      1 stop  In-flight meal not included           21              5
# 3      1 stop                      No info           21              5
# 4    non-stop                      No info           24              6
#
#    Dep_hour  Dep_min  Arrival_hour  Arrival_min
# 0        17       30             4           25
# ...

# %% [markdown]
# in this we have added 2 columns like arrival_hour and arrival_min and remove arrival time.

# %%
test_df['Airline'].value_counts()
# Out:
# Jet Airways                          897
# IndiGo                               511
# Air India                            440
# Multiple carriers                    347
# SpiceJet                             208
# Vistara                              129
# Air Asia                              86
# GoAir                                 46
# Multiple carriers Premium economy      3
# Vistara Premium economy                2
# Jet Airways Business                   2
# Name: Airline, dtype: int64

# %% [markdown]
# in this we can see the no. of value counts of column 'airline'.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.catplot(y='Price',x='Airline',data=train_df.sort_values('Price',ascending=False),kind='boxen',height=6,aspect=3)
plt.show()

# %% [markdown]
# we can see the x axis represent the airlines and y axis reprersents the prices, as we can see that jet airways has the highest prices as compared to other airlines.

# %%
train_df['Source'].value_counts()
# Out:
# Delhi       4536
# Kolkata     2871
# Banglore    2197
# Mumbai       697
# Chennai      381
# Name: Source, dtype: int64

# %% [markdown]
# in this we can see the city wise records from the 'source' column from the train dataset

# %%
sns.catplot(y='Price',x='Source',data=train_df.sort_values('Price',ascending=False),kind='boxen',height=6,aspect=3)
plt.show()

# %% [markdown]
# in this we can see the there is more outliers present in 'Banglore' as compared other cities.

# %%
train_df['Destination'].value_counts()
# Out:
# Cochin       4536
# Banglore     2871
# Delhi        1265
# New Delhi     932
# Hyderabad     697
# Kolkata       381
# Name: Destination, dtype: int64

# %% [markdown]
# we see here city wise destination like coachin has the highest 'Destination' is 4536

# %%
sns.catplot(y='Price',x='Destination',data=train_df.sort_values('Price',ascending=False),kind='boxen',height=6,aspect=3)
plt.show()

# %% [markdown]
# here we can see the price wise destination also we see that New delhi has the maximum outliers present in the graph.

# %%
train_df['Total_Stops'].value_counts()
# Out:
# 1 stop      5625
# non-stop    3491
# 2 stops     1520
# 3 stops       45
# 4 stops        1
# Name: Total_Stops, dtype: int64

# %% [markdown]
# we see that total no. of stops when the airline is reaching its destination.

# %%
train_df_visualization_nominal=train_df[['Airline','Source','Destination','Route','Total_Stops','Additional_Info','Price','Journey_day','Journey_month','Dep_hour','Dep_min','Arrival_hour','Arrival_min']].copy()

# %%
train_df_visualization_nominal.columns
# Out:
# Index(['Airline', 'Source', 'Destination', 'Route', 'Total_Stops',
#        'Additional_Info', 'Price', 'Journey_day', 'Journey_month', 'Dep_hour',
#        'Dep_min', 'Arrival_hour', 'Arrival_min'],
#       dtype='object')

# %% [markdown]
# in this we are making the train dataframe into a nominal data

# %%
ax=sns.countplot(x='Total_Stops',data=train_df_visualization_nominal)

# %% [markdown]
# from the above grapth we see that the total no. of stops flight is having 1 stop is more as compared to non stop, 2 stops, 3 stops and 4 stops.

# %%
ax=sns.countplot(x='Dep_hour',data=train_df_visualization_nominal)
print(train_df_visualization_nominal['Dep_hour'].value_counts())
# Out:
# 9     915
# 7     867
# 8     697
# 17    695
# 6     687
# 20    651
# 5     629
# 11    580
# 19    567
# 10    536
# 14    523
# 21    492
# 16    472
# 18    444
# 13    417
# 22    387
# 15    319
# 2     194
# 12    178
# 4     170
# 23    161
# 0      40
# 1      37
# 3      24
# Name: Dep_hour, dtype: int64

# %% [markdown]
# from ther above graph we can see the hours wise departure of flights

# %%
ax=sns.countplot(x='Journey_day',data=train_df_visualization_nominal)
print(train_df_visualization_nominal['Journey_day'].value_counts())
# Out:
# 9     1406
# 6     1287
# 27    1130
# 21    1111
# 1     1075
# 24    1052
# 15     984
# 12     957
# 3      848
# 18     832
# Name: Journey_day, dtype: int64

# %% [markdown]
# in this we can see the day wise journey of flights.

# %%
train_df['Journey_day'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# there is no outliers present in journer day column.

# %%
train_df['Dep_min'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# in this we can see there is no outlier present in Dep_min columns of train dataset

# %%
plt.subplots(figsize=(20,10))
ax=sns.countplot(x='Route',data=train_df_visualization_nominal)
print(train_df_visualization_nominal['Route'].value_counts())
# Out:
# DEL → BOM → COK                2376
# BLR → DEL                      1552
# CCU → BOM → BLR                 979
# CCU → BLR                       724
# BOM → HYD                       621
#                                ...
# BOM → CCU → HYD                   1
# CCU → IXZ → MAA → BLR             1
# BLR → HBX → BOM → BHO → DEL       1
# BOM → JLR → HYD                   1
# BOM → NDC → HYD                   1
# Name: Route, Length: 128, dtype: int64

# %% [markdown]
# in this we can see the route wise graph of flights.

# %%
plt.subplots(figsize=(22,8))
ax=sns.countplot(x='Additional_Info',data=train_df_visualization_nominal)
print(train_df_visualization_nominal['Additional_Info'].value_counts())
# Out:
# No info                         8344
# In-flight meal not included     1982
# No check-in baggage included     320
# 1 Long layover                    19
# Change airports                    7
# Business class                     4
# No Info                            3
# 2 Long layover                     1
# 1 Short layover                    1
# Red-eye flight                     1
# Name: Additional_Info, dtype: int64

# %% [markdown]
# from this grapth we observed that there is 'no info' reaches at maximum is 8344 as compared to other any information source.

# %%
sns.pairplot(train_df)

# %% [markdown]
# this shows the correaltion between columns and target variables of dataset

# %%
test_df_visualization_nominal=test_df[['Airline','Source','Destination','Route','Total_Stops','Additional_Info','Journey_day','Journey_month','Dep_hour','Dep_min','Arrival_hour','Arrival_min']].copy()

# %%
test_df_visualization_nominal.columns
# Out:
# Index(['Airline', 'Source', 'Destination', 'Route', 'Total_Stops',
#        'Additional_Info', 'Journey_day', 'Journey_month', 'Dep_hour',
#        'Dep_min', 'Arrival_hour', 'Arrival_min'],
#       dtype='object')

# %%
plt.subplots(figsize=(22,8))
ax=sns.countplot(x='Airline',data=test_df_visualization_nominal)
print(test_df_visualization_nominal['Airline'].value_counts())
# Out:
# Jet Airways                          897
# IndiGo                               511
# Air India                            440
# Multiple carriers                    347
# SpiceJet                             208
# Vistara                              129
# Air Asia                              86
# GoAir                                 46
# Multiple carriers Premium economy      3
# Vistara Premium economy                2
# Jet Airways Business                   2
# Name: Airline, dtype: int64

# %% [markdown]
# as we can see the jet airways has the highest no. of values counts is 897 as comapred to other airlines.

# %%
plt.subplots(figsize=(22,8))
ax=sns.countplot(x='Source',data=test_df_visualization_nominal)
print(test_df_visualization_nominal['Source'].value_counts())
# Out:
# Delhi       1145
# Kolkata      710
# Banglore     555
# Mumbai       186
# Chennai       75
# Name: Source, dtype: int64

# %% [markdown]
# from the above graph we can see that delhi city has the highest no. source as compared to other cities.

# %%
ax=sns.countplot(x='Destination',data=test_df_visualization_nominal)
print(test_df_visualization_nominal['Destination'].value_counts())
# Out:
# Cochin       1145
# Banglore      710
# Delhi         317
# New Delhi     238
# Hyderabad     186
# Kolkata        75
# Name: Destination, dtype: int64

# %% [markdown]
# in this we can see the coachin has the highest no. destination of flights.

# %%
plt.subplots(figsize=(22,8))
ax=sns.countplot(x='Route',data=test_df_visualization_nominal)
print(test_df_visualization_nominal['Route'].value_counts())
# Out:
# DEL → BOM → COK          624
# BLR → DEL                389
# CCU → BOM → BLR          253
# CCU → BLR                172
# BOM → HYD                164
#                         ...
# BOM → IXC → DEL → HYD      1
# BLR → GOI → DEL            1
# CCU → IXR → BBI → BLR      1
# CCU → AMD → BLR            1
# BLR → GAU → DEL            1
# Name: Route, Length: 100, dtype: int64

# %% [markdown]
# in this we can see the route wise data as we observed that flights has the highest no. of routes of del-bom-cok is 624 as compared to other routes.

# %%
ax=sns.countplot(x='Total_Stops',data=test_df_visualization_nominal)
print(test_df_visualization_nominal['Total_Stops'].value_counts())
# Out:
# 1 stop      1431
# non-stop     849
# 2 stops      379
# 3 stops       11
# 4 stops        1
# Name: Total_Stops, dtype: int64

# %% [markdown]
# from the above grapth we see that the total no. of stops flight is having 1 stop is more as compared to non stop, 2 stops, 3 stops and 4 stops.

# %%
plt.subplots(figsize=(22,8))
ax=sns.countplot(x='Additional_Info',data=test_df_visualization_nominal)
print(test_df_visualization_nominal['Additional_Info'].value_counts())
# Out:
# No info                         2148
# In-flight meal not included      444
# No check-in baggage included      76
# Business class                     1
# 1 Long layover                     1
# Change airports                    1
# Name: Additional_Info, dtype: int64

# %% [markdown]
# from this grapth we observed that there is 'no info' reaches at maximum is 2148 as compared to other any information source.

# %%
sns.catplot(y='Additional_Info',x='Airline',data=test_df.sort_values('Additional_Info',ascending=False),kind='boxen',height=6,aspect=3)
plt.show()

# %% [markdown]
# As we can see the some outliers exist when we see the correlation between additional info and Airlines.

# %%
sns.catplot(y='Airline',x='Total_Stops',data=test_df.sort_values('Airline',ascending=False),kind='boxen',height=6,aspect=3)
plt.show()

# %% [markdown]
# As we can see the some outliers exist when we comapring the no. of airline having the total no. of stops in their journey.

# %%
sns.pairplot(test_df)

# %% [markdown]
# this shows the correlation between columns and target variables of test dataset.

# %%
sns.heatmap(train_df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# there in no missing value found in all the column features of train dataset.

# %%
sns.heatmap(test_df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# there in no missing value found in all the column features of test dataset.

# %%
from sklearn.preprocessing import OrdinalEncoder
enc=OrdinalEncoder()

# %%
for i in train_df.columns:
    if train_df[i].dtypes=='object':
        train_df[i]=enc.fit_transform(train_df[i].values.reshape(-1,1))

# %%
train_df
# Out:
#        Airline  Source  Destination  Route  Total_Stops  Additional_Info  \
# 0          3.0     0.0          5.0   18.0          4.0              8.0
# 1          1.0     3.0          0.0   84.0          1.0              8.0
# 2          4.0     2.0          1.0  118.0          1.0              8.0
# 3          3.0     3.0          0.0   91.0          0.0              8.0
# 4          3.0     0.0          5.0   29.0          0.0              8.0
# ...        ...     ...          ...    ...          ...              ...
# 10678      0.0     3.0          0.0   64.0          4.0              8.0
# 10679      1.0     3.0          0.0   64.0          4.0              8.0
# 10680      4.0     0.0          2.0   18.0          4.0              8.0
# 10681     10.0     0.0          5.0   18.0          4.0              8.0
# 10682      1.0     2.0          1.0  108.0          1.0              8.0
#
#        Price  Journey_day  Journey_month  Dep_hour  Dep_min  Arrival_hour  \
# ...

# %% [markdown]
# now we have 10682 rows and 13 columns after apply ordinal encoder.

# %%
from scipy.stats import zscore
z=np.abs(zscore(train_df))

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([  123,   396,   486,   510,   597,   628,   657,   785,   785,
#          826,   936,   946,   959,   975,  1043,  1196,  1246,  1341,
#         1424,  1466,  1478,  1629,  1654,  1785,  1918,  2055,  2079,
#         2099,  2108,  2405,  2481,  2495,  2495,  2556,  2556,  2618,
#         2635,  2693,  2924,  2924,  3032,  3032,  3111,  3111,  3257,
#         3400,  3535,  3700,  3700,  3788,  4012,  4521,  4521,  4676,
#         4829,  5013,  5013,  5136,  5372,  5372,  5439,  5628,  5662,
#         5701,  5710,  5719,  5738,  5745,  5856,  5986,  6024,  6314,
#         6336,  6407,  6576,  6576,  6588,  6605,  6991,  7351,  7356,
#         7377,  7537,  7554,  7617,  7713,  7724,  7724,  7756,  7902,
#         8020,  8080,  8451,  8470,  8536,  8598,  8856,  8940,  8957,
#         8957,  8990,  9019,  9019,  9192,  9238,  9631,  9656,  9714,
#         9973, 10051, 10112, 10159, 10181, 10188, 10352, 10363, 10363,
# ...

# %% [markdown]
# This shows the z score value when zscr>3 and threshold value is equal to 3.

# %%
z[5745][3]
# Out:
# 1.9010416367860608

# %% [markdown]
# this shows the z score value of 5745th row from the dataset when threshold value is 3.

# %%
z[597][3]
# Out:
# 0.6485680055821893

# %% [markdown]
# this shows the z score value of 597th row from the dataset when threshold value is 3.

# %%
for i in test_df.columns:
    if test_df[i].dtypes=='object':
        test_df[i]=enc.fit_transform(test_df[i].values.reshape(-1,1))

# %%
test_df
# Out:
#       Airline  Source  Destination  Route  Duration  Total_Stops  \
# 0         4.0     2.0          1.0   76.0      10.0          0.0
# 1         3.0     3.0          0.0   65.0     248.0          0.0
# 2         4.0     2.0          1.0   76.0     148.0          0.0
# 3         6.0     2.0          1.0   76.0      36.0          0.0
# 4         0.0     0.0          2.0   16.0     216.0          4.0
# ...       ...     ...          ...    ...       ...          ...
# 2666      1.0     3.0          0.0   51.0     150.0          0.0
# 2667      3.0     3.0          0.0   43.0     213.0          4.0
# 2668      4.0     2.0          1.0   76.0     278.0          0.0
# 2669      1.0     2.0          1.0   76.0      60.0          0.0
# 2670      6.0     2.0          1.0   76.0      49.0          0.0
#
#       Additional_Info  Journey_day  Journey_month  Dep_hour  Dep_min  \
# 0                 5.0            6              6        17       30
# ...

# %% [markdown]
# in this we have 2671 rows and 13 columns after applying ordinal encoder.

# %%
from scipy.stats import zscore
z=np.abs(zscore(test_df))

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([ 954, 1802, 1861], dtype=int64), array([6, 6, 6], dtype=int64))

# %% [markdown]
# This shows the z score value when zscr>3 and threshold value is equal to 3.

# %%
z[954][3]
# Out:
# 1.8196643752448385

# %% [markdown]
# this shows the z score value of 954th row from the dataset when threshold value is 3.

# %%
train_df.skew()
# Out:
# Airline            0.731057
# Source            -0.424023
# Destination        1.244046
# Route             -0.501911
# Total_Stops        0.631532
# Additional_Info   -1.779689
# Price              1.812405
# Journey_day        0.118174
# Journey_month     -0.387409
# Dep_hour           0.112924
# Dep_min            0.167234
# Arrival_hour      -0.370146
# Arrival_min        0.110945
# dtype: float64

# %% [markdown]
# this shows the skewness of the trainn dataset.

# %%
test_df.skew()
# Out:
# Airline            0.483882
# Source            -0.424997
# Destination        1.263630
# Route             -0.281807
# Duration          -0.275404
# Total_Stops        0.672623
# Additional_Info   -1.719119
# Journey_day        0.199540
# Journey_month     -0.403700
# Dep_hour           0.093759
# Dep_min            0.128515
# Arrival_hour      -0.443166
# Arrival_min        0.115267
# dtype: float64

# %% [markdown]
# this shows the skewness of test dataset

# %%
train_df.corr()
# Out:
#                   Airline    Source  Destination     Route  Total_Stops  \
# Airline          1.000000 -0.013397     0.018446  0.025214     0.035973
# Source          -0.013397  1.000000    -0.592576  0.403412    -0.225605
# Destination      0.018446 -0.592576     1.000000 -0.461176     0.337872
# Route            0.025214  0.403412    -0.461176  1.000000    -0.437749
# Total_Stops      0.035973 -0.225605     0.337872 -0.437749     1.000000
# Additional_Info -0.060748 -0.022109     0.026821  0.035152     0.164054
# Price           -0.039565  0.015999    -0.071122  0.164149    -0.571221
# Journey_day      0.026137  0.004902    -0.041025  0.081632     0.029225
# Journey_month    0.024674  0.183268    -0.364682  0.244186    -0.026328
# Dep_hour        -0.035269  0.059047    -0.072997 -0.075002     0.039224
# Dep_min         -0.059922 -0.056998     0.127931 -0.068071     0.048901
# Arrival_hour    -0.007567  0.025635    -0.039729  0.013898    -0.095650
# ...

# %% [markdown]
# this shows the correlation between features of train dataset

# %%
corr_hmap=train_df.corr()
plt.figure(figsize=(10,8))
sns.heatmap(corr_hmap,annot=True)
plt.show()

# %% [markdown]
# As we can see from the above graph the correlation between destination and source feature is highly negatively correalted with value 0.59

# %%
test_df.corr()
# Out:
#                   Airline    Source  Destination     Route  Duration  \
# Airline          1.000000 -0.031107     0.033630  0.023995  0.027559
# Source          -0.031107  1.000000    -0.578296  0.339434 -0.169256
# Destination      0.033630 -0.578296     1.000000 -0.444760 -0.007661
# Route            0.023995  0.339434    -0.444760  1.000000 -0.053478
# Duration         0.027559 -0.169256    -0.007661 -0.053478  1.000000
# Total_Stops      0.039236 -0.212995     0.331240 -0.441772  0.197855
# Additional_Info -0.084423 -0.025205     0.026295  0.059682  0.051093
# Journey_day      0.000293 -0.032604    -0.011200  0.046097  0.009128
# Journey_month    0.049111  0.170430    -0.352907  0.235999 -0.009777
# Dep_hour         0.003731  0.056065    -0.049023 -0.137575  0.074146
# Dep_min         -0.047850 -0.064886     0.153330 -0.045161  0.030295
# Arrival_hour    -0.018313  0.001719    -0.004945  0.003447  0.041983
# Arrival_min     -0.097714 -0.008304     0.037196 -0.213024  0.082718
#
# ...

# %% [markdown]
# this shows the correlation between features of test dataset.

# %%
corr_hmap=test_df.corr()
plt.figure(figsize=(10,8))
sns.heatmap(corr_hmap,annot=True)
plt.show()

# %% [markdown]
# from the above graph we again observed that the correlation between destination and source feature is highly negatively correalted with value 0.58

# %%
x=train_df.iloc[:,0:-1]
x.head()
# Out:
#    Airline  Source  Destination  Route  Total_Stops  Additional_Info  Price  \
# 0      3.0     0.0          5.0   18.0          4.0              8.0   3897
# 1      1.0     3.0          0.0   84.0          1.0              8.0   7662
# 2      4.0     2.0          1.0  118.0          1.0              8.0  13882
# 3      3.0     3.0          0.0   91.0          0.0              8.0   6218
# 4      3.0     0.0          5.0   29.0          0.0              8.0  13302
#
#    Journey_day  Journey_month  Dep_hour  Dep_min  Arrival_hour
# 0           24              3        22       20             1
# 1            1              5         5       50            13
# 2            9              6         9       25             4
# 3           12              5        18        5            23
# 4            1              3        16       50            21

# %%
y=train_df.iloc[:,-1]
y.head()
# Out:
# 0    10
# 1    15
# 2    25
# 3    30
# 4    35
# Name: Arrival_min, dtype: int64

# %%
x.shape
# Out:
# (10682, 12)

# %%
y.shape
# Out:
# (10682,)

# %%
from sklearn.preprocessing import MinMaxScaler
mms=MinMaxScaler()
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings('ignore')

# %%
for i in range(0,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=i)
    lr.fit(x_train,y_train)
    pred_train=lr.predict(x_train)
    pred_test=lr.predict(x_test)
    print(f'At random state{i},the training accuracy is:- {r2_score(y_train,pred_train)}')
    print(f'At random state{i},the testing accuracy is:- {r2_score(y_test,pred_test)}')
    print('\n')
# Out:
# At random state0,the training accuracy is:- 0.09902444845456804
# At random state0,the testing accuracy is:- 0.07304510348802573
#
#
# At random state1,the training accuracy is:- 0.09519910224260908
# At random state1,the testing accuracy is:- 0.08866754109383412
#
#
# At random state2,the training accuracy is:- 0.09285852363882952
# At random state2,the testing accuracy is:- 0.09819745220925735
#
#
# At random state3,the training accuracy is:- 0.09196160896669336
# At random state3,the testing accuracy is:- 0.1015906866853109
#
#
# At random state4,the training accuracy is:- 0.08562616188413497
# At random state4,the testing accuracy is:- 0.12480772557936104
#
#
# At random state5,the training accuracy is:- 0.09887305281536596
# At random state5,the testing accuracy is:- 0.072899307183807
#
#
# At random state6,the training accuracy is:- 0.08980535170629123
# At random state6,the testing accuracy is:- 0.10826735298164514
#
#
# ...

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train.shape
# Out:
# (8545, 12)

# %%
y_train.shape
# Out:
# (8545,)

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
pred_test=lr.predict(x_test)

# %%
print(r2_score(y_test,pred_test))
# Out:
# 0.10719387836533001

# %% [markdown]
# r2 score is 0.1071938 approx

# %%
train_accuracy=r2_score(y_train,pred_train)
test_accuracy=r2_score(y_test,pred_test)

from sklearn.model_selection import cross_val_score
for j in range(2,10):
    cv_score=cross_val_score(lr,x,y,cv=j)
    cv_mean=cv_score.mean()
    print(f'At cross fold {j} the cv score is {cv_mean} and accuracy score for traning is {train_accuracy} and accuracy for the testing is  {r2_score(y_test,pred_test)}')
    print('\n')
# Out:
# At cross fold 2 the cv score is 0.09129822480103167 and accuracy score for traning is -0.10535006438749361 and accuracy for the testing is  0.10719387836533001
#
#
# At cross fold 3 the cv score is 0.09239450880033014 and accuracy score for traning is -0.10535006438749361 and accuracy for the testing is  0.10719387836533001
#
#
# At cross fold 4 the cv score is 0.09145722499336406 and accuracy score for traning is -0.10535006438749361 and accuracy for the testing is  0.10719387836533001
#
#
# At cross fold 5 the cv score is 0.09100661089404802 and accuracy score for traning is -0.10535006438749361 and accuracy for the testing is  0.10719387836533001
#
#
# At cross fold 6 the cv score is 0.09188597501548522 and accuracy score for traning is -0.10535006438749361 and accuracy for the testing is  0.10719387836533001
#
#
# At cross fold 7 the cv score is 0.0915045264904725 and accuracy score for traning is -0.10535006438749361 and accuracy for the testing is  0.10719387836533001
#
#
# ...

# %% [markdown]
# since the no. of folds  don't have much impact on the accuarcy

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor

parameters={'criterion':['mse','mae'],'max_features':['auto','sqrt','log2']}
rf=RandomForestRegressor()
clf=GridSearchCV(rf,parameters)
clf.fit(x_train,y_train)
print(clf.best_params_)
# Out:
# {'criterion': 'mae', 'max_features': 'auto'}

# %%
rf=RandomForestRegressor(criterion='mae',max_features='auto')
rf.fit(x_train,y_train)
rf.score(x_train,y_train)
pred_decision=rf.predict(x_test)

# %%
rfs=r2_score(y_test,pred_decision)
print('R2 Score:',rfs*100)
rfscore=cross_val_score(rf,x,y,cv=5)
rfc=rfscore.mean()
print('Cross Val Score:',rfc*100)
# Out:
# R2 Score: 95.97548761975918
# Cross Val Score: 95.2686933323928

# %% [markdown]
# in this we can see the R2 score is approx 96 and cross val score approx 95.26

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor

parameters={'criterion':['mse','mae'],'max_features':['auto','sqrt','log2']}
dt=DecisionTreeRegressor()
clf=GridSearchCV(dt,parameters)
clf.fit(x_train,y_train)
print(clf.best_params_)
# Out:
# {'criterion': 'mae', 'max_features': 'auto'}

# %%
dt=DecisionTreeRegressor(criterion='mae',max_features='auto')
dt.fit(x_train,y_train)
dt.score(x_train,y_train)
pred_decision=dt.predict(x_test)

# %%
dts=r2_score(y_test,pred_decision)
print('R2 Score:',dts*100)
dtscore=cross_val_score(rf,x,y,cv=5)
dtc=dtscore.mean()
print('Cross Val Score:',dtc*100)
# Out:
# R2 Score: 94.13040996563336
# Cross Val Score: 95.28887584670873

# %% [markdown]
# here we can see r2 score is approx 94.13 and cross valiadation score is 95.28

# %% [markdown]
# from the above calculation we can see random forest model accuracy and cross validation both as 95% approx which shows that our model performing well.

# %%
import pickle
filename='flightpriceprediction.pkl'
pickle.dump(rf,open(filename,'wb'))

# %%
loaded_model=pickle.load(open('flightpriceprediction.pkl','rb'))
result=loaded_model.score(x_train,y_train)
print(result)
# Out:
# 0.9910347275829362

# %% [markdown]
# the model score is approx 99%

# %%
import pickle
filename='flightpriceprediction.pkl'
pickle.dump(dt,open(filename,'wb'))

# %%
loaded_model=pickle.load(open('flightpriceprediction.pkl','rb'))
result=loaded_model.score(x_train,y_train)
print(result)
# Out:
# 0.998185494072145

# %% [markdown]
# the model score of decision tree regresor alomost 100%

# %%
import pickle
filename='flightpriceprediction.pkl'
pickle.dump(lr,open(filename,'wb'))

# %%
loaded_model=pickle.load(open('flightpriceprediction.pkl','rb'))
result=loaded_model.score(x_train,y_train)
print(result)
# Out:
# 0.0904945751822116

# %% [markdown]
# the linear regression model score is 0.09049

# %%
conclusion=pd.DataFrame([loaded_model.predict(x_test)[:],pred_decision[:]],index=['predicted','original'])

# %%
conclusion
# Out:
#                 0          1          2        3          4         5     \
# predicted  25.617281  18.374313  25.304048  19.1872  24.302916  17.76805
# original   30.000000  35.000000   5.000000   5.0000  25.000000   0.00000
#
#                 6          7          8          9     ...       2127  \
# predicted  18.649325  30.193133  21.888048  18.640349  ...  27.427746
# original    0.000000   5.000000  50.000000   0.000000  ...  25.000000
#
#                 2128       2129       2130       2131       2132       2133  \
# predicted  17.706075  15.220436  25.158067  15.717611  15.234669  31.368924
# original   15.000000  30.000000  20.000000   0.000000   0.000000  45.000000
#
#                 2134       2135       2136
# predicted  19.985868  23.480176  21.519895
# original   25.000000  25.000000  35.000000
#
# [2 rows x 2137 columns]

# %% [markdown]
# from above we can see the final conclusion of our dataset.
